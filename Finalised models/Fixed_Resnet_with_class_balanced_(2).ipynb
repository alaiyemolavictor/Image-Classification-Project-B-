# %% [markdown]
# # Facial Expression Classification — FER-2013
# ## Model 1: ResNet50V2 Transfer Learning with Image Augmentation

# %%
# Install kaggle if not already installed
# !pip install kaggle -q

# %%
# ── Core imports ──────────────────────────────────────────────
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import tensorflow as tf

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50V2
from tensorflow.keras import layers, models, optimizers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.models import Sequential, Model
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.layers import *
from tensorflow.keras import mixed_precision
mixed_precision.set_global_policy('mixed_float16')
print('TensorFlow version:', tf.__version__)
print('GPU available:', tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow version: 2.20.0
# GPU available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# ── Kaggle authentication ──────────────────────────────────────
# Upload your kaggle.json first via Files panel on the left
os.makedirs('/root/.kaggle', exist_ok=True)
# !cp kaggle.json /root/.kaggle/
# !chmod 600 /root/.kaggle/kaggle.json
print('Kaggle API key configured.')
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory
# Kaggle API key configured.

# %%
# ── Download and unzip FER-2013 dataset ───────────────────────
# !kaggle datasets download -d msambare/fer2013 --force
# !unzip -o fer2013.zip -d fer2013_data
print('Dataset ready.')
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: fer2013_data/train/sad/Training_65267116.jpg
#   inflating: fer2013_data/train/sad/Training_65275626.jpg
#   inflating: fer2013_data/train/sad/Training_6529266.jpg
#   inflating: fer2013_data/train/sad/Training_65329617.jpg
#   inflating: fer2013_data/train/sad/Training_65338712.jpg
#   inflating: fer2013_data/train/sad/Training_65338797.jpg
#   inflating: fer2013_data/train/sad/Training_65387162.jpg
#   inflating: fer2013_data/train/sad/Training_65404494.jpg
#   inflating: fer2013_data/train/sad/Training_65426218.jpg
#   inflating: fer2013_data/train/sad/Training_65430136.jpg
#   inflating: fer2013_data/train/sad/Training_65437377.jpg
#   inflating: fer2013_data/train/sad/Training_6545735.jpg
#   inflating: fer2013_data/train/sad/Training_65463385.jpg
#   inflating: fer2013_data/train/sad/Training_65473985.jpg
#   inflating: fer2013_data/train/sad/Training_65502829.jpg
#   inflating: fer2013_data/train/sad/Training_65505359.jpg
#   inflating: fer2013_data/train/sad/Training_65508578.jpg
#   inflating: fer2013_data/train/sad/Training_65516023.jpg
#   inflating: fer2013_data/train/sad/Training_65524027.jpg
#   inflating: fer2013_data/train/sad/Training_65526454.jpg
#   inflating: fer2013_data/train/sad/Training_65531175.jpg
#   inflating: fer2013_data/train/sad/Training_65552921.jpg
#   inflating: fer2013_data/train/sad/Training_65552938.jpg
#   inflating: fer2013_data/train/sad/Training_65563105.jpg
#   inflating: fer2013_data/train/sad/Training_6558295.jpg
#   inflating: fer2013_data/train/sad/Training_65586139.jpg
#   inflating: fer2013_data/train/sad/Training_65591252.jpg
#   inflating: fer2013_data/train/sad/Training_65626778.jpg
#   inflating: fer2013_data/train/sad/Training_65701260.jpg
#   inflating: fer2013_data/train/sad/Training_65707197.jpg
#   inflating: fer2013_data/train/sad/Training_65720898.jpg
#   inflating: fer2013_data/train/sad/Training_6573454.jpg
#   inflating: fer2013_data/train/sad/Training_65749670.jpg
#   inflating: fer2013_data/train/sad/Training_65756896.jpg
#   inflating: fer2013_data/train/sad/Training_65792953.jpg
#   inflating: fer2013_data/train/sad/Training_65814968.jpg
#   inflating: fer2013_data/train/sad/Training_65872739.jpg
#   inflating: fer2013_data/train/sad/Training_65887072.jpg
#   inflating: fer2013_data/train/sad/Training_65899637.jpg
#   inflating: fer2013_data/train/sad/Training_65930243.jpg
#   inflating: fer2013_data/train/sad/Training_65931697.jpg
#   inflating: fer2013_data/train/sad/Training_66006689.jpg
#   inflating: fer2013_data/train/sad/Training_66018355.jpg
#   inflating: fer2013_data/train/sad/Training_66025411.jpg
#   inflating: fer2013_data/train/sad/Training_6604778.jpg
#   inflating: fer2013_data/train/sad/Training_66064111.jpg
#   inflating: fer2013_data/train/sad/Training_66092447.jpg
#   inflating: fer2013_data/train/sad/Training_66106251.jpg
#   inflating: fer2013_data/train/sad/Training_6613286.jpg
#   inflating: fer2013_data/train/sad/Training_66137005.jpg
#   inflating: fer2013_data/train/sad/Training_66146242.jpg
#   inflating: fer2013_data/train/sad/Training_66186083.jpg
#   inflating: fer2013_data/train/sad/Training_66222142.jpg
#   inflating: fer2013_data/train/sad/Training_66241554.jpg
#   inflating: fer2013_data/train/sad/Training_66243450.jpg
#   inflating: fer2013_data/train/sad/Training_66270296.jpg
#   inflating: fer2013_data/train/sad/Training_66273436.jpg
#   inflating: fer2013_data/train/sad/Training_6627432.jpg
#   inflating: fer2013_data/train/sad/Training_66292901.jpg
#   inflating: fer2013_data/train/sad/Training_6632070.jpg
#   inflating: fer2013_data/train/sad/Training_66345107.jpg
#   inflating: fer2013_data/train/sad/Training_66358284.jpg
#   inflating: fer2013_data/train/sad/Training_66374624.jpg
#   inflating: fer2013_data/train/sad/Training_66374947.jpg
#   inflating: fer2013_data/train/sad/Training_66449545.jpg
#   inflating: fer2013_data/train/sad/Training_66465496.jpg
#   inflating: fer2013_data/train/sad/Training_66485665.jpg
#   inflating: fer2013_data/train/sad/Training_66503867.jpg
#   inflating: fer2013_data/train/sad/Training_66511942.jpg
#   inflating: fer2013_data/train/sad/Training_66514659.jpg
#   inflating: fer2013_data/train/sad/Training_66538546.jpg
#   inflating: fer2013_data/train/sad/Training_66548047.jpg
#   inflating: fer2013_data/train/sad/Training_66550587.jpg
#   inflating: fer2013_data/train/sad/Training_66564605.jpg
#   inflating: fer2013_data/train/sad/Training_66598359.jpg
#   inflating: fer2013_data/train/sad/Training_6660320.jpg
#   inflating: fer2013_data/train/sad/Training_66613149.jpg
#   inflating: fer2013_data/train/sad/Training_66618356.jpg
#   inflating: fer2013_data/train/sad/Training_66621180.jpg
#   inflating: fer2013_data/train/sad/Training_66632167.jpg
#   inflating: fer2013_data/train/sad/Training_66633227.jpg
#   inflating: fer2013_data/train/sad/Training_66665516.jpg
#   inflating: fer2013_data/train/sad/Training_66670996.jpg
#   inflating: fer2013_data/train/sad/Training_66677994.jpg
#   inflating: fer2013_data/train/sad/Training_66678590.jpg
#   inflating: fer2013_data/train/sad/Training_66688298.jpg
#   inflating: fer2013_data/train/sad/Training_66705535.jpg
#   inflating: fer2013_data/train/sad/Training_66717644.jpg
#   inflating: fer2013_data/train/sad/Training_66723931.jpg
#   inflating: fer2013_data/train/sad/Training_66743020.jpg
#   inflating: fer2013_data/train/sad/Training_66758555.jpg
#   inflating: fer2013_data/train/sad/Training_66776704.jpg
#   inflating: fer2013_data/train/sad/Training_66778513.jpg
#   inflating: fer2013_data/train/sad/Training_66782106.jpg
#   inflating: fer2013_data/train/sad/Training_66801083.jpg
#   inflating: fer2013_data/train/sad/Training_66812358.jpg
#   inflating: fer2013_data/train/sad/Training_66816897.jpg
#   inflating: fer2013_data/train/sad/Training_66834181.jpg
#   inflating: fer2013_data/train/sad/Training_66836105.jpg
#   inflating: fer2013_data/train/sad/Training_66860349.jpg
#   inflating: fer2013_data/train/sad/Training_66885032.jpg
#   inflating: fer2013_data/train/sad/Training_66932713.jpg
#   inflating: fer2013_data/train/sad/Training_66967267.jpg
#   inflating: fer2013_data/train/sad/Training_66980527.jpg
#   inflating: fer2013_data/train/sad/Training_67003784.jpg
#   inflating: fer2013_data/train/sad/Training_67009167.jpg
#   inflating: fer2013_data/train/sad/Training_67015623.jpg
#   inflating: fer2013_data/train/sad/Training_67021882.jpg
#   inflating: fer2013_data/train/sad/Training_6704458.jpg
#   inflating: fer2013_data/train/sad/Training_67046287.jpg
#   inflating: fer2013_data/train/sad/Training_67063417.jpg
#   inflating: fer2013_data/train/sad/Training_67094111.jpg
#   inflating: fer2013_data/train/sad/Training_67118841.jpg
#   inflating: fer2013_data/train/sad/Training_67152521.jpg
#   inflating: fer2013_data/train/sad/Training_6716869.jpg
#   inflating: fer2013_data/train/sad/Training_67169851.jpg
#   inflating: fer2013_data/train/sad/Training_67218522.jpg
#   inflating: fer2013_data/train/sad/Training_67220863.jpg
#   inflating: fer2013_data/train/sad/Training_67244109.jpg
#   inflating: fer2013_data/train/sad/Training_67244736.jpg
#   inflating: fer2013_data/train/sad/Training_67277941.jpg
#   inflating: fer2013_data/train/sad/Training_67317150.jpg
#   inflating: fer2013_data/train/sad/Training_6733844.jpg
#   inflating: fer2013_data/train/sad/Training_67341114.jpg
#   inflating: fer2013_data/train/sad/Training_67345736.jpg
#   inflating: fer2013_data/train/sad/Training_6736373.jpg
#   inflating: fer2013_data/train/sad/Training_6736561.jpg
#   inflating: fer2013_data/train/sad/Training_67385672.jpg
#   inflating: fer2013_data/train/sad/Training_67400475.jpg
#   inflating: fer2013_data/train/sad/Training_67405401.jpg
#   inflating: fer2013_data/train/sad/Training_67418316.jpg
#   inflating: fer2013_data/train/sad/Training_6745845.jpg
#   inflating: fer2013_data/train/sad/Training_67467856.jpg
#   inflating: fer2013_data/train/sad/Training_67468920.jpg
#   inflating: fer2013_data/train/sad/Training_6748595.jpg
#   inflating: fer2013_data/train/sad/Training_67493222.jpg
#   inflating: fer2013_data/train/sad/Training_67528776.jpg
#   inflating: fer2013_data/train/sad/Training_67536310.jpg
#   inflating: fer2013_data/train/sad/Training_67556790.jpg
#   inflating: fer2013_data/train/sad/Training_67572813.jpg
#   inflating: fer2013_data/train/sad/Training_67591540.jpg
#   inflating: fer2013_data/train/sad/Training_67632832.jpg
#   inflating: fer2013_data/train/sad/Training_67669944.jpg
#   inflating: fer2013_data/train/sad/Training_67692740.jpg
#   inflating: fer2013_data/train/sad/Training_67708546.jpg
#   inflating: fer2013_data/train/sad/Training_67745215.jpg
#   inflating: fer2013_data/train/sad/Training_6777216.jpg
#   inflating: fer2013_data/train/sad/Training_67804138.jpg
#   inflating: fer2013_data/train/sad/Training_67813483.jpg
#   inflating: fer2013_data/train/sad/Training_67817866.jpg
#   inflating: fer2013_data/train/sad/Training_67818179.jpg
#   inflating: fer2013_data/train/sad/Training_67828892.jpg
#   inflating: fer2013_data/train/sad/Training_67837331.jpg
#   inflating: fer2013_data/train/sad/Training_67842276.jpg
#   inflating: fer2013_data/train/sad/Training_67850543.jpg
#   inflating: fer2013_data/train/sad/Training_67851920.jpg
#   inflating: fer2013_data/train/sad/Training_67882996.jpg
#   inflating: fer2013_data/train/sad/Training_67966108.jpg
#   inflating: fer2013_data/train/sad/Training_67985555.jpg
#   inflating: fer2013_data/train/sad/Training_68037479.jpg
#   inflating: fer2013_data/train/sad/Training_68045022.jpg
#   inflating: fer2013_data/train/sad/Training_68076888.jpg
#   inflating: fer2013_data/train/sad/Training_68089357.jpg
#   inflating: fer2013_data/train/sad/Training_68103747.jpg
#   inflating: fer2013_data/train/sad/Training_68128382.jpg
#   inflating: fer2013_data/train/sad/Training_68142058.jpg
#   inflating: fer2013_data/train/sad/Training_68159604.jpg
#   inflating: fer2013_data/train/sad/Training_68171793.jpg
#   inflating: fer2013_data/train/sad/Training_68200153.jpg
#   inflating: fer2013_data/train/sad/Training_68202501.jpg
#   inflating: fer2013_data/train/sad/Training_68244029.jpg
#   inflating: fer2013_data/train/sad/Training_68256652.jpg
#   inflating: fer2013_data/train/sad/Training_68280493.jpg
#   inflating: fer2013_data/train/sad/Training_68289103.jpg
#   inflating: fer2013_data/train/sad/Training_68290755.jpg
#   inflating: fer2013_data/train/sad/Training_6830318.jpg
#   inflating: fer2013_data/train/sad/Training_68307224.jpg
#   inflating: fer2013_data/train/sad/Training_68335728.jpg
#   inflating: fer2013_data/train/sad/Training_68370333.jpg
#   inflating: fer2013_data/train/sad/Training_68385314.jpg
#   inflating: fer2013_data/train/sad/Training_68408675.jpg
#   inflating: fer2013_data/train/sad/Training_6842792.jpg
#   inflating: fer2013_data/train/sad/Training_68430686.jpg
#   inflating: fer2013_data/train/sad/Training_68442333.jpg
#   inflating: fer2013_data/train/sad/Training_68473473.jpg
#   inflating: fer2013_data/train/sad/Training_68482325.jpg
#   inflating: fer2013_data/train/sad/Training_68484367.jpg
#   inflating: fer2013_data/train/sad/Training_68551663.jpg
#   inflating: fer2013_data/train/sad/Training_68571709.jpg
#   inflating: fer2013_data/train/sad/Training_68592359.jpg
#   inflating: fer2013_data/train/sad/Training_68595440.jpg
#   inflating: fer2013_data/train/sad/Training_68604461.jpg
#   inflating: fer2013_data/train/sad/Training_68638288.jpg
#   inflating: fer2013_data/train/sad/Training_68646641.jpg
#   inflating: fer2013_data/train/sad/Training_68688296.jpg
#   inflating: fer2013_data/train/sad/Training_68694648.jpg
#   inflating: fer2013_data/train/sad/Training_68710853.jpg
#   inflating: fer2013_data/train/sad/Training_68716255.jpg
#   inflating: fer2013_data/train/sad/Training_68738998.jpg
#   inflating: fer2013_data/train/sad/Training_68768411.jpg
#   inflating: fer2013_data/train/sad/Training_68779876.jpg
#   inflating: fer2013_data/train/sad/Training_68810853.jpg
#   inflating: fer2013_data/train/sad/Training_68836974.jpg
#   inflating: fer2013_data/train/sad/Training_68865659.jpg
#   inflating: fer2013_data/train/sad/Training_68875064.jpg
#   inflating: fer2013_data/train/sad/Training_68899646.jpg
#   inflating: fer2013_data/train/sad/Training_68936141.jpg
#   inflating: fer2013_data/train/sad/Training_69062237.jpg
#   inflating: fer2013_data/train/sad/Training_69151004.jpg
#   inflating: fer2013_data/train/sad/Training_69164072.jpg
#   inflating: fer2013_data/train/sad/Training_69206174.jpg
#   inflating: fer2013_data/train/sad/Training_69210256.jpg
#   inflating: fer2013_data/train/sad/Training_69241506.jpg
#   inflating: fer2013_data/train/sad/Training_69269398.jpg
#   inflating: fer2013_data/train/sad/Training_69291124.jpg
#   inflating: fer2013_data/train/sad/Training_6930508.jpg
#   inflating: fer2013_data/train/sad/Training_69334317.jpg
#   inflating: fer2013_data/train/sad/Training_69378971.jpg
#   inflating: fer2013_data/train/sad/Training_69382895.jpg
#   inflating: fer2013_data/train/sad/Training_69389790.jpg
#   inflating: fer2013_data/train/sad/Training_6939143.jpg
#   inflating: fer2013_data/train/sad/Training_69394388.jpg
#   inflating: fer2013_data/train/sad/Training_69395556.jpg
#   inflating: fer2013_data/train/sad/Training_69400238.jpg
#   inflating: fer2013_data/train/sad/Training_6947104.jpg
#   inflating: fer2013_data/train/sad/Training_6956023.jpg
#   inflating: fer2013_data/train/sad/Training_69563111.jpg
#   inflating: fer2013_data/train/sad/Training_69571000.jpg
#   inflating: fer2013_data/train/sad/Training_69615702.jpg
#   inflating: fer2013_data/train/sad/Training_69620341.jpg
#   inflating: fer2013_data/train/sad/Training_69633580.jpg
#   inflating: fer2013_data/train/sad/Training_69666372.jpg
#   inflating: fer2013_data/train/sad/Training_696816.jpg
#   inflating: fer2013_data/train/sad/Training_69690698.jpg
#   inflating: fer2013_data/train/sad/Training_69755939.jpg
#   inflating: fer2013_data/train/sad/Training_69757572.jpg
#   inflating: fer2013_data/train/sad/Training_69762456.jpg
#   inflating: fer2013_data/train/sad/Training_69763599.jpg
#   inflating: fer2013_data/train/sad/Training_69767645.jpg
#   inflating: fer2013_data/train/sad/Training_6977677.jpg
#   inflating: fer2013_data/train/sad/Training_69784078.jpg
#   inflating: fer2013_data/train/sad/Training_69814836.jpg
#   inflating: fer2013_data/train/sad/Training_69827762.jpg
#   inflating: fer2013_data/train/sad/Training_69845699.jpg
#   inflating: fer2013_data/train/sad/Training_69860257.jpg
#   inflating: fer2013_data/train/sad/Training_69861683.jpg
#   inflating: fer2013_data/train/sad/Training_69878041.jpg
#   inflating: fer2013_data/train/sad/Training_69897977.jpg
#   inflating: fer2013_data/train/sad/Training_69912786.jpg
#   inflating: fer2013_data/train/sad/Training_69919251.jpg
#   inflating: fer2013_data/train/sad/Training_69936046.jpg
#   inflating: fer2013_data/train/sad/Training_69939023.jpg
#   inflating: fer2013_data/train/sad/Training_69942887.jpg
#   inflating: fer2013_data/train/sad/Training_69945584.jpg
#   inflating: fer2013_data/train/sad/Training_69969238.jpg
#   inflating: fer2013_data/train/sad/Training_69982805.jpg
#   inflating: fer2013_data/train/sad/Training_6999681.jpg
#   inflating: fer2013_data/train/sad/Training_70035377.jpg
#   inflating: fer2013_data/train/sad/Training_70080960.jpg
#   inflating: fer2013_data/train/sad/Training_70091553.jpg
#   inflating: fer2013_data/train/sad/Training_70114086.jpg
#   inflating: fer2013_data/train/sad/Training_70161018.jpg
#   inflating: fer2013_data/train/sad/Training_70207644.jpg
#   inflating: fer2013_data/train/sad/Training_70229937.jpg
#   inflating: fer2013_data/train/sad/Training_70262923.jpg
#   inflating: fer2013_data/train/sad/Training_70266380.jpg
#   inflating: fer2013_data/train/sad/Training_70296904.jpg
#   inflating: fer2013_data/train/sad/Training_70297947.jpg
#   inflating: fer2013_data/train/sad/Training_70321234.jpg
#   inflating: fer2013_data/train/sad/Training_70378996.jpg
#   inflating: fer2013_data/train/sad/Training_70421844.jpg
#   inflating: fer2013_data/train/sad/Training_70436848.jpg
#   inflating: fer2013_data/train/sad/Training_7044634.jpg
#   inflating: fer2013_data/train/sad/Training_7045780.jpg
#   inflating: fer2013_data/train/sad/Training_70461378.jpg
#   inflating: fer2013_data/train/sad/Training_70521844.jpg
#   inflating: fer2013_data/train/sad/Training_70536939.jpg
#   inflating: fer2013_data/train/sad/Training_70583207.jpg
#   inflating: fer2013_data/train/sad/Training_70596208.jpg
#   inflating: fer2013_data/train/sad/Training_70599552.jpg
#   inflating: fer2013_data/train/sad/Training_70603263.jpg
#   inflating: fer2013_data/train/sad/Training_70607796.jpg
#   inflating: fer2013_data/train/sad/Training_70612607.jpg
#   inflating: fer2013_data/train/sad/Training_70634821.jpg
#   inflating: fer2013_data/train/sad/Training_706365.jpg
#   inflating: fer2013_data/train/sad/Training_70651275.jpg
#   inflating: fer2013_data/train/sad/Training_70662488.jpg
#   inflating: fer2013_data/train/sad/Training_70676169.jpg
#   inflating: fer2013_data/train/sad/Training_70678059.jpg
#   inflating: fer2013_data/train/sad/Training_70701274.jpg
#   inflating: fer2013_data/train/sad/Training_70718370.jpg
#   inflating: fer2013_data/train/sad/Training_70733870.jpg
#   inflating: fer2013_data/train/sad/Training_70769976.jpg
#   inflating: fer2013_data/train/sad/Training_70823629.jpg
#   inflating: fer2013_data/train/sad/Training_70934098.jpg
#   inflating: fer2013_data/train/sad/Training_70940444.jpg
#   inflating: fer2013_data/train/sad/Training_7095418.jpg
#   inflating: fer2013_data/train/sad/Training_70958370.jpg
#   inflating: fer2013_data/train/sad/Training_70958870.jpg
#   inflating: fer2013_data/train/sad/Training_70964123.jpg
#   inflating: fer2013_data/train/sad/Training_71007211.jpg
#   inflating: fer2013_data/train/sad/Training_71011588.jpg
#   inflating: fer2013_data/train/sad/Training_71037244.jpg
#   inflating: fer2013_data/train/sad/Training_71082937.jpg
#   inflating: fer2013_data/train/sad/Training_71115241.jpg
#   inflating: fer2013_data/train/sad/Training_71138337.jpg
#   inflating: fer2013_data/train/sad/Training_7117589.jpg
#   inflating: fer2013_data/train/sad/Training_71188788.jpg
#   inflating: fer2013_data/train/sad/Training_71196994.jpg
#   inflating: fer2013_data/train/sad/Training_71288773.jpg
#   inflating: fer2013_data/train/sad/Training_71288801.jpg
#   inflating: fer2013_data/train/sad/Training_71292002.jpg
#   inflating: fer2013_data/train/sad/Training_71292204.jpg
#   inflating: fer2013_data/train/sad/Training_71296493.jpg
#   inflating: fer2013_data/train/sad/Training_71310081.jpg
#   inflating: fer2013_data/train/sad/Training_71318950.jpg
#   inflating: fer2013_data/train/sad/Training_71334011.jpg
#   inflating: fer2013_data/train/sad/Training_71353503.jpg
#   inflating: fer2013_data/train/sad/Training_71419058.jpg
#   inflating: fer2013_data/train/sad/Training_71447345.jpg
#   inflating: fer2013_data/train/sad/Training_71451863.jpg
#   inflating: fer2013_data/train/sad/Training_71476978.jpg
#   inflating: fer2013_data/train/sad/Training_71488385.jpg
#   inflating: fer2013_data/train/sad/Training_71512023.jpg
#   inflating: fer2013_data/train/sad/Training_71527594.jpg
#   inflating: fer2013_data/train/sad/Training_71554470.jpg
#   inflating: fer2013_data/train/sad/Training_71570678.jpg
#   inflating: fer2013_data/train/sad/Training_71584150.jpg
#   inflating: fer2013_data/train/sad/Training_71584967.jpg
#   inflating: fer2013_data/train/sad/Training_71622452.jpg
#   inflating: fer2013_data/train/sad/Training_71627161.jpg
#   inflating: fer2013_data/train/sad/Training_7164832.jpg
#   inflating: fer2013_data/train/sad/Training_71649758.jpg
#   inflating: fer2013_data/train/sad/Training_71661069.jpg
#   inflating: fer2013_data/train/sad/Training_71669823.jpg
#   inflating: fer2013_data/train/sad/Training_7167918.jpg
#   inflating: fer2013_data/train/sad/Training_7170574.jpg
#   inflating: fer2013_data/train/sad/Training_71721961.jpg
#   inflating: fer2013_data/train/sad/Training_71776823.jpg
#   inflating: fer2013_data/train/sad/Training_71843157.jpg
#   inflating: fer2013_data/train/sad/Training_71883695.jpg
#   inflating: fer2013_data/train/sad/Training_71898080.jpg
#   inflating: fer2013_data/train/sad/Training_71898542.jpg
#   inflating: fer2013_data/train/sad/Training_71902821.jpg
#   inflating: fer2013_data/train/sad/Training_71934607.jpg
#   inflating: fer2013_data/train/sad/Training_71958451.jpg
#   inflating: fer2013_data/train/sad/Training_71976355.jpg
#   inflating: fer2013_data/train/sad/Training_71998111.jpg
#   inflating: fer2013_data/train/sad/Training_72047639.jpg
#   inflating: fer2013_data/train/sad/Training_72083858.jpg
#   inflating: fer2013_data/train/sad/Training_7209166.jpg
#   inflating: fer2013_data/train/sad/Training_72093577.jpg
#   inflating: fer2013_data/train/sad/Training_72099142.jpg
#   inflating: fer2013_data/train/sad/Training_72102844.jpg
#   inflating: fer2013_data/train/sad/Training_72110672.jpg
#   inflating: fer2013_data/train/sad/Training_72146177.jpg
#   inflating: fer2013_data/train/sad/Training_7215018.jpg
#   inflating: fer2013_data/train/sad/Training_72163737.jpg
#   inflating: fer2013_data/train/sad/Training_72173801.jpg
#   inflating: fer2013_data/train/sad/Training_72222596.jpg
#   inflating: fer2013_data/train/sad/Training_72224302.jpg
#   inflating: fer2013_data/train/sad/Training_72235014.jpg
#   inflating: fer2013_data/train/sad/Training_72253699.jpg
#   inflating: fer2013_data/train/sad/Training_72271772.jpg
#   inflating: fer2013_data/train/sad/Training_7228651.jpg
#   inflating: fer2013_data/train/sad/Training_72295557.jpg
#   inflating: fer2013_data/train/sad/Training_72325011.jpg
#   inflating: fer2013_data/train/sad/Training_72337521.jpg
#   inflating: fer2013_data/train/sad/Training_72338337.jpg
#   inflating: fer2013_data/train/sad/Training_72344183.jpg
#   inflating: fer2013_data/train/sad/Training_72346725.jpg
#   inflating: fer2013_data/train/sad/Training_72378190.jpg
#   inflating: fer2013_data/train/sad/Training_72389603.jpg
#   inflating: fer2013_data/train/sad/Training_72395127.jpg
#   inflating: fer2013_data/train/sad/Training_72399943.jpg
#   inflating: fer2013_data/train/sad/Training_72409954.jpg
#   inflating: fer2013_data/train/sad/Training_72460884.jpg
#   inflating: fer2013_data/train/sad/Training_72469576.jpg
#   inflating: fer2013_data/train/sad/Training_72496252.jpg
#   inflating: fer2013_data/train/sad/Training_72542126.jpg
#   inflating: fer2013_data/train/sad/Training_72569474.jpg
#   inflating: fer2013_data/train/sad/Training_72581485.jpg
#   inflating: fer2013_data/train/sad/Training_72591909.jpg
#   inflating: fer2013_data/train/sad/Training_72597782.jpg
#   inflating: fer2013_data/train/sad/Training_72611574.jpg
#   inflating: fer2013_data/train/sad/Training_72611844.jpg
#   inflating: fer2013_data/train/sad/Training_72615912.jpg
#   inflating: fer2013_data/train/sad/Training_72634633.jpg
#   inflating: fer2013_data/train/sad/Training_72643390.jpg
#   inflating: fer2013_data/train/sad/Training_72654049.jpg
#   inflating: fer2013_data/train/sad/Training_7269195.jpg
#   inflating: fer2013_data/train/sad/Training_72720479.jpg
#   inflating: fer2013_data/train/sad/Training_72723295.jpg
#   inflating: fer2013_data/train/sad/Training_7275452.jpg
#   inflating: fer2013_data/train/sad/Training_72762537.jpg
#   inflating: fer2013_data/train/sad/Training_72778292.jpg
#   inflating: fer2013_data/train/sad/Training_72783691.jpg
#   inflating: fer2013_data/train/sad/Training_72811320.jpg
#   inflating: fer2013_data/train/sad/Training_72840504.jpg
#   inflating: fer2013_data/train/sad/Training_72841025.jpg
#   inflating: fer2013_data/train/sad/Training_72863073.jpg
#   inflating: fer2013_data/train/sad/Training_72896318.jpg
#   inflating: fer2013_data/train/sad/Training_72903645.jpg
#   inflating: fer2013_data/train/sad/Training_7298615.jpg
#   inflating: fer2013_data/train/sad/Training_73008225.jpg
#   inflating: fer2013_data/train/sad/Training_73009287.jpg
#   inflating: fer2013_data/train/sad/Training_73009503.jpg
#   inflating: fer2013_data/train/sad/Training_73037101.jpg
#   inflating: fer2013_data/train/sad/Training_73046118.jpg
#   inflating: fer2013_data/train/sad/Training_73057152.jpg
#   inflating: fer2013_data/train/sad/Training_73057687.jpg
#   inflating: fer2013_data/train/sad/Training_73058352.jpg
#   inflating: fer2013_data/train/sad/Training_73075893.jpg
#   inflating: fer2013_data/train/sad/Training_73092569.jpg
#   inflating: fer2013_data/train/sad/Training_73106861.jpg
#   inflating: fer2013_data/train/sad/Training_73109136.jpg
#   inflating: fer2013_data/train/sad/Training_73157275.jpg
#   inflating: fer2013_data/train/sad/Training_73179474.jpg
#   inflating: fer2013_data/train/sad/Training_73180212.jpg
#   inflating: fer2013_data/train/sad/Training_73180906.jpg
#   inflating: fer2013_data/train/sad/Training_73192317.jpg
#   inflating: fer2013_data/train/sad/Training_73207709.jpg
#   inflating: fer2013_data/train/sad/Training_73215932.jpg
#   inflating: fer2013_data/train/sad/Training_73221082.jpg
#   inflating: fer2013_data/train/sad/Training_73221224.jpg
#   inflating: fer2013_data/train/sad/Training_73230439.jpg
#   inflating: fer2013_data/train/sad/Training_73353739.jpg
#   inflating: fer2013_data/train/sad/Training_73359813.jpg
#   inflating: fer2013_data/train/sad/Training_73361195.jpg
#   inflating: fer2013_data/train/sad/Training_73374075.jpg
#   inflating: fer2013_data/train/sad/Training_73381526.jpg
#   inflating: fer2013_data/train/sad/Training_7338492.jpg
#   inflating: fer2013_data/train/sad/Training_73393003.jpg
#   inflating: fer2013_data/train/sad/Training_73408195.jpg
#   inflating: fer2013_data/train/sad/Training_73440556.jpg
#   inflating: fer2013_data/train/sad/Training_73491794.jpg
#   inflating: fer2013_data/train/sad/Training_73514241.jpg
#   inflating: fer2013_data/train/sad/Training_73517508.jpg
#   inflating: fer2013_data/train/sad/Training_73530752.jpg
#   inflating: fer2013_data/train/sad/Training_73535020.jpg
#   inflating: fer2013_data/train/sad/Training_73550785.jpg
#   inflating: fer2013_data/train/sad/Training_73563278.jpg
#   inflating: fer2013_data/train/sad/Training_73569064.jpg
#   inflating: fer2013_data/train/sad/Training_73593223.jpg
#   inflating: fer2013_data/train/sad/Training_7360259.jpg
#   inflating: fer2013_data/train/sad/Training_73619612.jpg
#   inflating: fer2013_data/train/sad/Training_73677468.jpg
#   inflating: fer2013_data/train/sad/Training_7368170.jpg
#   inflating: fer2013_data/train/sad/Training_7368650.jpg
#   inflating: fer2013_data/train/sad/Training_73704673.jpg
#   inflating: fer2013_data/train/sad/Training_73743414.jpg
#   inflating: fer2013_data/train/sad/Training_73768093.jpg
#   inflating: fer2013_data/train/sad/Training_73771138.jpg
#   inflating: fer2013_data/train/sad/Training_73806297.jpg
#   inflating: fer2013_data/train/sad/Training_73814276.jpg
#   inflating: fer2013_data/train/sad/Training_73815301.jpg
#   inflating: fer2013_data/train/sad/Training_73821059.jpg
#   inflating: fer2013_data/train/sad/Training_73825583.jpg
#   inflating: fer2013_data/train/sad/Training_73841476.jpg
#   inflating: fer2013_data/train/sad/Training_73846262.jpg
#   inflating: fer2013_data/train/sad/Training_73882625.jpg
#   inflating: fer2013_data/train/sad/Training_73884877.jpg
#   inflating: fer2013_data/train/sad/Training_73899462.jpg
#   inflating: fer2013_data/train/sad/Training_73913636.jpg
#   inflating: fer2013_data/train/sad/Training_73922667.jpg
#   inflating: fer2013_data/train/sad/Training_73928625.jpg
#   inflating: fer2013_data/train/sad/Training_73954004.jpg
#   inflating: fer2013_data/train/sad/Training_73972027.jpg
#   inflating: fer2013_data/train/sad/Training_73991927.jpg
#   inflating: fer2013_data/train/sad/Training_73996544.jpg
#   inflating: fer2013_data/train/sad/Training_7401108.jpg
#   inflating: fer2013_data/train/sad/Training_74023330.jpg
#   inflating: fer2013_data/train/sad/Training_74033981.jpg
#   inflating: fer2013_data/train/sad/Training_74065266.jpg
#   inflating: fer2013_data/train/sad/Training_74072045.jpg
#   inflating: fer2013_data/train/sad/Training_74080914.jpg
#   inflating: fer2013_data/train/sad/Training_74093072.jpg
#   inflating: fer2013_data/train/sad/Training_74101198.jpg
#   inflating: fer2013_data/train/sad/Training_74105412.jpg
#   inflating: fer2013_data/train/sad/Training_7410773.jpg
#   inflating: fer2013_data/train/sad/Training_74136066.jpg
#   inflating: fer2013_data/train/sad/Training_74136619.jpg
#   inflating: fer2013_data/train/sad/Training_74152534.jpg
#   inflating: fer2013_data/train/sad/Training_7415406.jpg
#   inflating: fer2013_data/train/sad/Training_7421898.jpg
#   inflating: fer2013_data/train/sad/Training_74279721.jpg
#   inflating: fer2013_data/train/sad/Training_74299759.jpg
#   inflating: fer2013_data/train/sad/Training_74350756.jpg
#   inflating: fer2013_data/train/sad/Training_74358544.jpg
#   inflating: fer2013_data/train/sad/Training_74368010.jpg
#   inflating: fer2013_data/train/sad/Training_74411661.jpg
#   inflating: fer2013_data/train/sad/Training_74414713.jpg
#   inflating: fer2013_data/train/sad/Training_74435111.jpg
#   inflating: fer2013_data/train/sad/Training_74470648.jpg
#   inflating: fer2013_data/train/sad/Training_74502717.jpg
#   inflating: fer2013_data/train/sad/Training_74568768.jpg
#   inflating: fer2013_data/train/sad/Training_74573435.jpg
#   inflating: fer2013_data/train/sad/Training_74579668.jpg
#   inflating: fer2013_data/train/sad/Training_74600155.jpg
#   inflating: fer2013_data/train/sad/Training_74603491.jpg
#   inflating: fer2013_data/train/sad/Training_74630860.jpg
#   inflating: fer2013_data/train/sad/Training_74647082.jpg
#   inflating: fer2013_data/train/sad/Training_74660658.jpg
#   inflating: fer2013_data/train/sad/Training_74663426.jpg
#   inflating: fer2013_data/train/sad/Training_74719415.jpg
#   inflating: fer2013_data/train/sad/Training_74729984.jpg
#   inflating: fer2013_data/train/sad/Training_74752869.jpg
#   inflating: fer2013_data/train/sad/Training_74779597.jpg
#   inflating: fer2013_data/train/sad/Training_74788956.jpg
#   inflating: fer2013_data/train/sad/Training_74803271.jpg
#   inflating: fer2013_data/train/sad/Training_74806656.jpg
#   inflating: fer2013_data/train/sad/Training_74832345.jpg
#   inflating: fer2013_data/train/sad/Training_74835832.jpg
#   inflating: fer2013_data/train/sad/Training_74837191.jpg
#   inflating: fer2013_data/train/sad/Training_74869127.jpg
#   inflating: fer2013_data/train/sad/Training_7492201.jpg
#   inflating: fer2013_data/train/sad/Training_74923508.jpg
#   inflating: fer2013_data/train/sad/Training_74935742.jpg
#   inflating: fer2013_data/train/sad/Training_74959363.jpg
#   inflating: fer2013_data/train/sad/Training_74965466.jpg
#   inflating: fer2013_data/train/sad/Training_74983244.jpg
#   inflating: fer2013_data/train/sad/Training_74994333.jpg
#   inflating: fer2013_data/train/sad/Training_74998300.jpg
#   inflating: fer2013_data/train/sad/Training_75008092.jpg
#   inflating: fer2013_data/train/sad/Training_75034927.jpg
#   inflating: fer2013_data/train/sad/Training_75067659.jpg
#   inflating: fer2013_data/train/sad/Training_75082078.jpg
#   inflating: fer2013_data/train/sad/Training_75083073.jpg
#   inflating: fer2013_data/train/sad/Training_75110513.jpg
#   inflating: fer2013_data/train/sad/Training_7513470.jpg
#   inflating: fer2013_data/train/sad/Training_75135222.jpg
#   inflating: fer2013_data/train/sad/Training_75159666.jpg
#   inflating: fer2013_data/train/sad/Training_75170083.jpg
#   inflating: fer2013_data/train/sad/Training_75171465.jpg
#   inflating: fer2013_data/train/sad/Training_75189928.jpg
#   inflating: fer2013_data/train/sad/Training_75214583.jpg
#   inflating: fer2013_data/train/sad/Training_7525300.jpg
#   inflating: fer2013_data/train/sad/Training_75262711.jpg
#   inflating: fer2013_data/train/sad/Training_75262873.jpg
#   inflating: fer2013_data/train/sad/Training_75274984.jpg
#   inflating: fer2013_data/train/sad/Training_75293540.jpg
#   inflating: fer2013_data/train/sad/Training_75313915.jpg
#   inflating: fer2013_data/train/sad/Training_75341606.jpg
#   inflating: fer2013_data/train/sad/Training_75350741.jpg
#   inflating: fer2013_data/train/sad/Training_75356262.jpg
#   inflating: fer2013_data/train/sad/Training_75368167.jpg
#   inflating: fer2013_data/train/sad/Training_75387198.jpg
#   inflating: fer2013_data/train/sad/Training_75410725.jpg
#   inflating: fer2013_data/train/sad/Training_75416581.jpg
#   inflating: fer2013_data/train/sad/Training_75416938.jpg
#   inflating: fer2013_data/train/sad/Training_75444602.jpg
#   inflating: fer2013_data/train/sad/Training_7549724.jpg
#   inflating: fer2013_data/train/sad/Training_75543640.jpg
#   inflating: fer2013_data/train/sad/Training_75543932.jpg
#   inflating: fer2013_data/train/sad/Training_75571535.jpg
#   inflating: fer2013_data/train/sad/Training_75610438.jpg
#   inflating: fer2013_data/train/sad/Training_75611272.jpg
#   inflating: fer2013_data/train/sad/Training_75618319.jpg
#   inflating: fer2013_data/train/sad/Training_75621135.jpg
#   inflating: fer2013_data/train/sad/Training_75624853.jpg
#   inflating: fer2013_data/train/sad/Training_75635467.jpg
#   inflating: fer2013_data/train/sad/Training_75646677.jpg
#   inflating: fer2013_data/train/sad/Training_75660322.jpg
#   inflating: fer2013_data/train/sad/Training_75700227.jpg
#   inflating: fer2013_data/train/sad/Training_75707572.jpg
#   inflating: fer2013_data/train/sad/Training_75719873.jpg
#   inflating: fer2013_data/train/sad/Training_75724813.jpg
#   inflating: fer2013_data/train/sad/Training_75727403.jpg
#   inflating: fer2013_data/train/sad/Training_75766217.jpg
#   inflating: fer2013_data/train/sad/Training_75787895.jpg
#   inflating: fer2013_data/train/sad/Training_75799681.jpg
#   inflating: fer2013_data/train/sad/Training_75848425.jpg
#   inflating: fer2013_data/train/sad/Training_75874059.jpg
#   inflating: fer2013_data/train/sad/Training_7587826.jpg
#   inflating: fer2013_data/train/sad/Training_75911539.jpg
#   inflating: fer2013_data/train/sad/Training_75913936.jpg
#   inflating: fer2013_data/train/sad/Training_75937447.jpg
#   inflating: fer2013_data/train/sad/Training_75981229.jpg
#   inflating: fer2013_data/train/sad/Training_75989216.jpg
#   inflating: fer2013_data/train/sad/Training_76033714.jpg
#   inflating: fer2013_data/train/sad/Training_76054912.jpg
#   inflating: fer2013_data/train/sad/Training_76072526.jpg
#   inflating: fer2013_data/train/sad/Training_76078228.jpg
#   inflating: fer2013_data/train/sad/Training_76093170.jpg
#   inflating: fer2013_data/train/sad/Training_76156703.jpg
#   inflating: fer2013_data/train/sad/Training_76172020.jpg
#   inflating: fer2013_data/train/sad/Training_76242403.jpg
#   inflating: fer2013_data/train/sad/Training_76247539.jpg
#   inflating: fer2013_data/train/sad/Training_76337396.jpg
#   inflating: fer2013_data/train/sad/Training_76350973.jpg
#   inflating: fer2013_data/train/sad/Training_76359569.jpg
#   inflating: fer2013_data/train/sad/Training_76420897.jpg
#   inflating: fer2013_data/train/sad/Training_76430810.jpg
#   inflating: fer2013_data/train/sad/Training_76476336.jpg
#   inflating: fer2013_data/train/sad/Training_76520571.jpg
#   inflating: fer2013_data/train/sad/Training_76521474.jpg
#   inflating: fer2013_data/train/sad/Training_76527846.jpg
#   inflating: fer2013_data/train/sad/Training_76572193.jpg
#   inflating: fer2013_data/train/sad/Training_765835.jpg
#   inflating: fer2013_data/train/sad/Training_76596885.jpg
#   inflating: fer2013_data/train/sad/Training_76640624.jpg
#   inflating: fer2013_data/train/sad/Training_76656854.jpg
#   inflating: fer2013_data/train/sad/Training_76673414.jpg
#   inflating: fer2013_data/train/sad/Training_76689888.jpg
#   inflating: fer2013_data/train/sad/Training_76693132.jpg
#   inflating: fer2013_data/train/sad/Training_76733432.jpg
#   inflating: fer2013_data/train/sad/Training_76753108.jpg
#   inflating: fer2013_data/train/sad/Training_76762566.jpg
#   inflating: fer2013_data/train/sad/Training_76775461.jpg
#   inflating: fer2013_data/train/sad/Training_76784987.jpg
#   inflating: fer2013_data/train/sad/Training_76791590.jpg
#   inflating: fer2013_data/train/sad/Training_76838629.jpg
#   inflating: fer2013_data/train/sad/Training_76873410.jpg
#   inflating: fer2013_data/train/sad/Training_76875172.jpg
#   inflating: fer2013_data/train/sad/Training_7688937.jpg
#   inflating: fer2013_data/train/sad/Training_76985291.jpg
#   inflating: fer2013_data/train/sad/Training_77016343.jpg
#   inflating: fer2013_data/train/sad/Training_77028632.jpg
#   inflating: fer2013_data/train/sad/Training_77047483.jpg
#   inflating: fer2013_data/train/sad/Training_77050371.jpg
#   inflating: fer2013_data/train/sad/Training_7705182.jpg
#   inflating: fer2013_data/train/sad/Training_77054367.jpg
#   inflating: fer2013_data/train/sad/Training_77080138.jpg
#   inflating: fer2013_data/train/sad/Training_7708402.jpg
#   inflating: fer2013_data/train/sad/Training_77113075.jpg
#   inflating: fer2013_data/train/sad/Training_77117966.jpg
#   inflating: fer2013_data/train/sad/Training_7711966.jpg
#   inflating: fer2013_data/train/sad/Training_771314.jpg
#   inflating: fer2013_data/train/sad/Training_77151653.jpg
#   inflating: fer2013_data/train/sad/Training_77158311.jpg
#   inflating: fer2013_data/train/sad/Training_77160993.jpg
#   inflating: fer2013_data/train/sad/Training_7718130.jpg
#   inflating: fer2013_data/train/sad/Training_77240805.jpg
#   inflating: fer2013_data/train/sad/Training_77313526.jpg
#   inflating: fer2013_data/train/sad/Training_77318703.jpg
#   inflating: fer2013_data/train/sad/Training_77332384.jpg
#   inflating: fer2013_data/train/sad/Training_77355699.jpg
#   inflating: fer2013_data/train/sad/Training_77361751.jpg
#   inflating: fer2013_data/train/sad/Training_77374373.jpg
#   inflating: fer2013_data/train/sad/Training_77375068.jpg
#   inflating: fer2013_data/train/sad/Training_77385699.jpg
#   inflating: fer2013_data/train/sad/Training_77394585.jpg
#   inflating: fer2013_data/train/sad/Training_77397756.jpg
#   inflating: fer2013_data/train/sad/Training_77411040.jpg
#   inflating: fer2013_data/train/sad/Training_77427125.jpg
#   inflating: fer2013_data/train/sad/Training_77502812.jpg
#   inflating: fer2013_data/train/sad/Training_77535999.jpg
#   inflating: fer2013_data/train/sad/Training_77538613.jpg
#   inflating: fer2013_data/train/sad/Training_77561478.jpg
#   inflating: fer2013_data/train/sad/Training_77592896.jpg
#   inflating: fer2013_data/train/sad/Training_77595440.jpg
#   inflating: fer2013_data/train/sad/Training_77621186.jpg
#   inflating: fer2013_data/train/sad/Training_77692339.jpg
#   inflating: fer2013_data/train/sad/Training_77708150.jpg
#   inflating: fer2013_data/train/sad/Training_77718583.jpg
#   inflating: fer2013_data/train/sad/Training_7776501.jpg
#   inflating: fer2013_data/train/sad/Training_77800976.jpg
#   inflating: fer2013_data/train/sad/Training_77824660.jpg
#   inflating: fer2013_data/train/sad/Training_77825744.jpg
#   inflating: fer2013_data/train/sad/Training_77846583.jpg
#   inflating: fer2013_data/train/sad/Training_77853230.jpg
#   inflating: fer2013_data/train/sad/Training_77866797.jpg
#   inflating: fer2013_data/train/sad/Training_77901137.jpg
#   inflating: fer2013_data/train/sad/Training_77907745.jpg
#   inflating: fer2013_data/train/sad/Training_7791103.jpg
#   inflating: fer2013_data/train/sad/Training_77919469.jpg
#   inflating: fer2013_data/train/sad/Training_77927007.jpg
#   inflating: fer2013_data/train/sad/Training_77938374.jpg
#   inflating: fer2013_data/train/sad/Training_77978390.jpg
#   inflating: fer2013_data/train/sad/Training_77992570.jpg
#   inflating: fer2013_data/train/sad/Training_77994782.jpg
#   inflating: fer2013_data/train/sad/Training_78060020.jpg
#   inflating: fer2013_data/train/sad/Training_78077558.jpg
#   inflating: fer2013_data/train/sad/Training_78106696.jpg
#   inflating: fer2013_data/train/sad/Training_78109009.jpg
#   inflating: fer2013_data/train/sad/Training_7811127.jpg
#   inflating: fer2013_data/train/sad/Training_78115403.jpg
#   inflating: fer2013_data/train/sad/Training_78130963.jpg
#   inflating: fer2013_data/train/sad/Training_78142280.jpg
#   inflating: fer2013_data/train/sad/Training_7816570.jpg
#   inflating: fer2013_data/train/sad/Training_78178750.jpg
#   inflating: fer2013_data/train/sad/Training_78191339.jpg
#   inflating: fer2013_data/train/sad/Training_78222724.jpg
#   inflating: fer2013_data/train/sad/Training_78226550.jpg
#   inflating: fer2013_data/train/sad/Training_78236652.jpg
#   inflating: fer2013_data/train/sad/Training_78244666.jpg
#   inflating: fer2013_data/train/sad/Training_78252572.jpg
#   inflating: fer2013_data/train/sad/Training_78259953.jpg
#   inflating: fer2013_data/train/sad/Training_78263773.jpg
#   inflating: fer2013_data/train/sad/Training_78280823.jpg
#   inflating: fer2013_data/train/sad/Training_78282619.jpg
#   inflating: fer2013_data/train/sad/Training_78304061.jpg
#   inflating: fer2013_data/train/sad/Training_78306602.jpg
#   inflating: fer2013_data/train/sad/Training_78310916.jpg
#   inflating: fer2013_data/train/sad/Training_78314397.jpg
#   inflating: fer2013_data/train/sad/Training_78323726.jpg
#   inflating: fer2013_data/train/sad/Training_78338992.jpg
#   inflating: fer2013_data/train/sad/Training_78363728.jpg
#   inflating: fer2013_data/train/sad/Training_78373088.jpg
#   inflating: fer2013_data/train/sad/Training_78374290.jpg
#   inflating: fer2013_data/train/sad/Training_78391775.jpg
#   inflating: fer2013_data/train/sad/Training_78444257.jpg
#   inflating: fer2013_data/train/sad/Training_78500318.jpg
#   inflating: fer2013_data/train/sad/Training_78512361.jpg
#   inflating: fer2013_data/train/sad/Training_78533904.jpg
#   inflating: fer2013_data/train/sad/Training_78537346.jpg
#   inflating: fer2013_data/train/sad/Training_78580473.jpg
#   inflating: fer2013_data/train/sad/Training_78637258.jpg
#   inflating: fer2013_data/train/sad/Training_78658686.jpg
#   inflating: fer2013_data/train/sad/Training_78698675.jpg
#   inflating: fer2013_data/train/sad/Training_78711005.jpg
#   inflating: fer2013_data/train/sad/Training_78713328.jpg
#   inflating: fer2013_data/train/sad/Training_78714614.jpg
#   inflating: fer2013_data/train/sad/Training_78744933.jpg
#   inflating: fer2013_data/train/sad/Training_78746497.jpg
#   inflating: fer2013_data/train/sad/Training_78771425.jpg
#   inflating: fer2013_data/train/sad/Training_78793953.jpg
#   inflating: fer2013_data/train/sad/Training_78798891.jpg
#   inflating: fer2013_data/train/sad/Training_78808789.jpg
#   inflating: fer2013_data/train/sad/Training_78818631.jpg
#   inflating: fer2013_data/train/sad/Training_78822832.jpg
#   inflating: fer2013_data/train/sad/Training_78842185.jpg
#   inflating: fer2013_data/train/sad/Training_78850836.jpg
#   inflating: fer2013_data/train/sad/Training_7885587.jpg
#   inflating: fer2013_data/train/sad/Training_78975310.jpg
#   inflating: fer2013_data/train/sad/Training_78985679.jpg
#   inflating: fer2013_data/train/sad/Training_78986879.jpg
#   inflating: fer2013_data/train/sad/Training_79032308.jpg
#   inflating: fer2013_data/train/sad/Training_79051384.jpg
#   inflating: fer2013_data/train/sad/Training_79061910.jpg
#   inflating: fer2013_data/train/sad/Training_79070746.jpg
#   inflating: fer2013_data/train/sad/Training_79079382.jpg
#   inflating: fer2013_data/train/sad/Training_79107437.jpg
#   inflating: fer2013_data/train/sad/Training_79108628.jpg
#   inflating: fer2013_data/train/sad/Training_79122693.jpg
#   inflating: fer2013_data/train/sad/Training_79140066.jpg
#   inflating: fer2013_data/train/sad/Training_79168469.jpg
#   inflating: fer2013_data/train/sad/Training_79170275.jpg
#   inflating: fer2013_data/train/sad/Training_79173226.jpg
#   inflating: fer2013_data/train/sad/Training_79185737.jpg
#   inflating: fer2013_data/train/sad/Training_7920978.jpg
#   inflating: fer2013_data/train/sad/Training_79234860.jpg
#   inflating: fer2013_data/train/sad/Training_79244828.jpg
#   inflating: fer2013_data/train/sad/Training_79258455.jpg
#   inflating: fer2013_data/train/sad/Training_79289652.jpg
#   inflating: fer2013_data/train/sad/Training_79345073.jpg
#   inflating: fer2013_data/train/sad/Training_79347036.jpg
#   inflating: fer2013_data/train/sad/Training_79348405.jpg
#   inflating: fer2013_data/train/sad/Training_79349140.jpg
#   inflating: fer2013_data/train/sad/Training_79376728.jpg
#   inflating: fer2013_data/train/sad/Training_79382417.jpg
#   inflating: fer2013_data/train/sad/Training_79397869.jpg
#   inflating: fer2013_data/train/sad/Training_79402229.jpg
#   inflating: fer2013_data/train/sad/Training_79422885.jpg
#   inflating: fer2013_data/train/sad/Training_79441584.jpg
#   inflating: fer2013_data/train/sad/Training_79446524.jpg
#   inflating: fer2013_data/train/sad/Training_79467007.jpg
#   inflating: fer2013_data/train/sad/Training_79471335.jpg
#   inflating: fer2013_data/train/sad/Training_79471378.jpg
#   inflating: fer2013_data/train/sad/Training_7958960.jpg
#   inflating: fer2013_data/train/sad/Training_79596916.jpg
#   inflating: fer2013_data/train/sad/Training_79598993.jpg
#   inflating: fer2013_data/train/sad/Training_79606094.jpg
#   inflating: fer2013_data/train/sad/Training_79680889.jpg
#   inflating: fer2013_data/train/sad/Training_79713448.jpg
#   inflating: fer2013_data/train/sad/Training_79726354.jpg
#   inflating: fer2013_data/train/sad/Training_79736851.jpg
#   inflating: fer2013_data/train/sad/Training_79741353.jpg
#   inflating: fer2013_data/train/sad/Training_79758901.jpg
#   inflating: fer2013_data/train/sad/Training_79776909.jpg
#   inflating: fer2013_data/train/sad/Training_79786488.jpg
#   inflating: fer2013_data/train/sad/Training_7979691.jpg
#   inflating: fer2013_data/train/sad/Training_79807922.jpg
#   inflating: fer2013_data/train/sad/Training_79815522.jpg
#   inflating: fer2013_data/train/sad/Training_79843120.jpg
#   inflating: fer2013_data/train/sad/Training_79860018.jpg
#   inflating: fer2013_data/train/sad/Training_79896402.jpg
#   inflating: fer2013_data/train/sad/Training_7991765.jpg
#   inflating: fer2013_data/train/sad/Training_79931718.jpg
#   inflating: fer2013_data/train/sad/Training_79948141.jpg
#   inflating: fer2013_data/train/sad/Training_79950523.jpg
#   inflating: fer2013_data/train/sad/Training_80017807.jpg
#   inflating: fer2013_data/train/sad/Training_80026827.jpg
#   inflating: fer2013_data/train/sad/Training_80030764.jpg
#   inflating: fer2013_data/train/sad/Training_8006911.jpg
#   inflating: fer2013_data/train/sad/Training_80112431.jpg
#   inflating: fer2013_data/train/sad/Training_80116947.jpg
#   inflating: fer2013_data/train/sad/Training_80125846.jpg
#   inflating: fer2013_data/train/sad/Training_80130045.jpg
#   inflating: fer2013_data/train/sad/Training_80184735.jpg
#   inflating: fer2013_data/train/sad/Training_80195598.jpg
#   inflating: fer2013_data/train/sad/Training_80204177.jpg
#   inflating: fer2013_data/train/sad/Training_80274936.jpg
#   inflating: fer2013_data/train/sad/Training_80331424.jpg
#   inflating: fer2013_data/train/sad/Training_80338672.jpg
#   inflating: fer2013_data/train/sad/Training_80348614.jpg
#   inflating: fer2013_data/train/sad/Training_80385070.jpg
#   inflating: fer2013_data/train/sad/Training_8039829.jpg
#   inflating: fer2013_data/train/sad/Training_8041120.jpg
#   inflating: fer2013_data/train/sad/Training_80441506.jpg
# ...
#   inflating: fer2013_data/train/surprise/Training_92587887.jpg
#   inflating: fer2013_data/train/surprise/Training_92595345.jpg
#   inflating: fer2013_data/train/surprise/Training_92606057.jpg
#   inflating: fer2013_data/train/surprise/Training_92608034.jpg
#   inflating: fer2013_data/train/surprise/Training_92638202.jpg
#   inflating: fer2013_data/train/surprise/Training_9263983.jpg
#   inflating: fer2013_data/train/surprise/Training_92652268.jpg
#   inflating: fer2013_data/train/surprise/Training_92666649.jpg
#   inflating: fer2013_data/train/surprise/Training_92701859.jpg
#   inflating: fer2013_data/train/surprise/Training_92768155.jpg
#   inflating: fer2013_data/train/surprise/Training_9278243.jpg
#   inflating: fer2013_data/train/surprise/Training_92846416.jpg
#   inflating: fer2013_data/train/surprise/Training_92923337.jpg
#   inflating: fer2013_data/train/surprise/Training_92984568.jpg
#   inflating: fer2013_data/train/surprise/Training_93006194.jpg
#   inflating: fer2013_data/train/surprise/Training_93037336.jpg
#   inflating: fer2013_data/train/surprise/Training_93055491.jpg
#   inflating: fer2013_data/train/surprise/Training_93101746.jpg
#   inflating: fer2013_data/train/surprise/Training_93122504.jpg
#   inflating: fer2013_data/train/surprise/Training_93172846.jpg
#   inflating: fer2013_data/train/surprise/Training_93342559.jpg
#   inflating: fer2013_data/train/surprise/Training_9340355.jpg
#   inflating: fer2013_data/train/surprise/Training_93417164.jpg
#   inflating: fer2013_data/train/surprise/Training_9342491.jpg
#   inflating: fer2013_data/train/surprise/Training_93442446.jpg
#   inflating: fer2013_data/train/surprise/Training_93443959.jpg
#   inflating: fer2013_data/train/surprise/Training_93474212.jpg
#   inflating: fer2013_data/train/surprise/Training_93492148.jpg
#   inflating: fer2013_data/train/surprise/Training_93560263.jpg
#   inflating: fer2013_data/train/surprise/Training_93625113.jpg
#   inflating: fer2013_data/train/surprise/Training_93625752.jpg
#   inflating: fer2013_data/train/surprise/Training_93642020.jpg
#   inflating: fer2013_data/train/surprise/Training_93658821.jpg
#   inflating: fer2013_data/train/surprise/Training_93675722.jpg
#   inflating: fer2013_data/train/surprise/Training_93699149.jpg
#   inflating: fer2013_data/train/surprise/Training_93713521.jpg
#   inflating: fer2013_data/train/surprise/Training_93735232.jpg
#   inflating: fer2013_data/train/surprise/Training_93742686.jpg
#   inflating: fer2013_data/train/surprise/Training_93744466.jpg
#   inflating: fer2013_data/train/surprise/Training_93747086.jpg
#   inflating: fer2013_data/train/surprise/Training_93918990.jpg
#   inflating: fer2013_data/train/surprise/Training_93922116.jpg
#   inflating: fer2013_data/train/surprise/Training_93942694.jpg
#   inflating: fer2013_data/train/surprise/Training_93944440.jpg
#   inflating: fer2013_data/train/surprise/Training_93981745.jpg
#   inflating: fer2013_data/train/surprise/Training_93997972.jpg
#   inflating: fer2013_data/train/surprise/Training_94014854.jpg
#   inflating: fer2013_data/train/surprise/Training_94108784.jpg
#   inflating: fer2013_data/train/surprise/Training_941343.jpg
#   inflating: fer2013_data/train/surprise/Training_94164371.jpg
#   inflating: fer2013_data/train/surprise/Training_9419936.jpg
#   inflating: fer2013_data/train/surprise/Training_94220119.jpg
#   inflating: fer2013_data/train/surprise/Training_94234220.jpg
#   inflating: fer2013_data/train/surprise/Training_94244032.jpg
#   inflating: fer2013_data/train/surprise/Training_94259743.jpg
#   inflating: fer2013_data/train/surprise/Training_9426774.jpg
#   inflating: fer2013_data/train/surprise/Training_9428441.jpg
#   inflating: fer2013_data/train/surprise/Training_94303347.jpg
#   inflating: fer2013_data/train/surprise/Training_94363754.jpg
#   inflating: fer2013_data/train/surprise/Training_94470519.jpg
#   inflating: fer2013_data/train/surprise/Training_94535865.jpg
#   inflating: fer2013_data/train/surprise/Training_94582829.jpg
#   inflating: fer2013_data/train/surprise/Training_94607952.jpg
#   inflating: fer2013_data/train/surprise/Training_94690773.jpg
#   inflating: fer2013_data/train/surprise/Training_94690831.jpg
#   inflating: fer2013_data/train/surprise/Training_94760289.jpg
#   inflating: fer2013_data/train/surprise/Training_94804140.jpg
#   inflating: fer2013_data/train/surprise/Training_94815054.jpg
#   inflating: fer2013_data/train/surprise/Training_94859807.jpg
#   inflating: fer2013_data/train/surprise/Training_94871392.jpg
#   inflating: fer2013_data/train/surprise/Training_94872292.jpg
#   inflating: fer2013_data/train/surprise/Training_94885610.jpg
#   inflating: fer2013_data/train/surprise/Training_94916496.jpg
#   inflating: fer2013_data/train/surprise/Training_94931391.jpg
#   inflating: fer2013_data/train/surprise/Training_95007623.jpg
#   inflating: fer2013_data/train/surprise/Training_95045198.jpg
#   inflating: fer2013_data/train/surprise/Training_95079686.jpg
#   inflating: fer2013_data/train/surprise/Training_95101558.jpg
#   inflating: fer2013_data/train/surprise/Training_95163599.jpg
#   inflating: fer2013_data/train/surprise/Training_95187678.jpg
#   inflating: fer2013_data/train/surprise/Training_95204802.jpg
#   inflating: fer2013_data/train/surprise/Training_95232145.jpg
#   inflating: fer2013_data/train/surprise/Training_95310908.jpg
#   inflating: fer2013_data/train/surprise/Training_95325414.jpg
#   inflating: fer2013_data/train/surprise/Training_95402552.jpg
#   inflating: fer2013_data/train/surprise/Training_95451817.jpg
#   inflating: fer2013_data/train/surprise/Training_95461460.jpg
#   inflating: fer2013_data/train/surprise/Training_95495690.jpg
#   inflating: fer2013_data/train/surprise/Training_95558533.jpg
#   inflating: fer2013_data/train/surprise/Training_95600814.jpg
#   inflating: fer2013_data/train/surprise/Training_95689131.jpg
#   inflating: fer2013_data/train/surprise/Training_95699837.jpg
#   inflating: fer2013_data/train/surprise/Training_95706228.jpg
#   inflating: fer2013_data/train/surprise/Training_95708850.jpg
#   inflating: fer2013_data/train/surprise/Training_95755746.jpg
#   inflating: fer2013_data/train/surprise/Training_95773470.jpg
#   inflating: fer2013_data/train/surprise/Training_95805741.jpg
#   inflating: fer2013_data/train/surprise/Training_95830400.jpg
#   inflating: fer2013_data/train/surprise/Training_95847480.jpg
#   inflating: fer2013_data/train/surprise/Training_95853103.jpg
#   inflating: fer2013_data/train/surprise/Training_95880970.jpg
#   inflating: fer2013_data/train/surprise/Training_95966009.jpg
#   inflating: fer2013_data/train/surprise/Training_95988339.jpg
#   inflating: fer2013_data/train/surprise/Training_95989089.jpg
#   inflating: fer2013_data/train/surprise/Training_9602572.jpg
#   inflating: fer2013_data/train/surprise/Training_96163000.jpg
#   inflating: fer2013_data/train/surprise/Training_96163370.jpg
#   inflating: fer2013_data/train/surprise/Training_96193805.jpg
#   inflating: fer2013_data/train/surprise/Training_96202596.jpg
#   inflating: fer2013_data/train/surprise/Training_96210289.jpg
#   inflating: fer2013_data/train/surprise/Training_96238543.jpg
#   inflating: fer2013_data/train/surprise/Training_96277880.jpg
#   inflating: fer2013_data/train/surprise/Training_96287206.jpg
#   inflating: fer2013_data/train/surprise/Training_96389125.jpg
#   inflating: fer2013_data/train/surprise/Training_96389792.jpg
#   inflating: fer2013_data/train/surprise/Training_96446762.jpg
#   inflating: fer2013_data/train/surprise/Training_96475488.jpg
#   inflating: fer2013_data/train/surprise/Training_96533198.jpg
#   inflating: fer2013_data/train/surprise/Training_96572434.jpg
#   inflating: fer2013_data/train/surprise/Training_96596500.jpg
#   inflating: fer2013_data/train/surprise/Training_96642531.jpg
#   inflating: fer2013_data/train/surprise/Training_96656714.jpg
#   inflating: fer2013_data/train/surprise/Training_96661519.jpg
#   inflating: fer2013_data/train/surprise/Training_96670821.jpg
#   inflating: fer2013_data/train/surprise/Training_96672701.jpg
#   inflating: fer2013_data/train/surprise/Training_96695026.jpg
#   inflating: fer2013_data/train/surprise/Training_96734839.jpg
#   inflating: fer2013_data/train/surprise/Training_9676011.jpg
#   inflating: fer2013_data/train/surprise/Training_96765324.jpg
#   inflating: fer2013_data/train/surprise/Training_96765430.jpg
#   inflating: fer2013_data/train/surprise/Training_96800478.jpg
#   inflating: fer2013_data/train/surprise/Training_96848455.jpg
#   inflating: fer2013_data/train/surprise/Training_96914394.jpg
#   inflating: fer2013_data/train/surprise/Training_96970066.jpg
#   inflating: fer2013_data/train/surprise/Training_97062924.jpg
#   inflating: fer2013_data/train/surprise/Training_97090047.jpg
#   inflating: fer2013_data/train/surprise/Training_97100020.jpg
#   inflating: fer2013_data/train/surprise/Training_97109955.jpg
#   inflating: fer2013_data/train/surprise/Training_97149632.jpg
#   inflating: fer2013_data/train/surprise/Training_97209154.jpg
#   inflating: fer2013_data/train/surprise/Training_97275390.jpg
#   inflating: fer2013_data/train/surprise/Training_97284057.jpg
#   inflating: fer2013_data/train/surprise/Training_97313556.jpg
#   inflating: fer2013_data/train/surprise/Training_97372586.jpg
#   inflating: fer2013_data/train/surprise/Training_97386553.jpg
#   inflating: fer2013_data/train/surprise/Training_97424717.jpg
#   inflating: fer2013_data/train/surprise/Training_97427205.jpg
#   inflating: fer2013_data/train/surprise/Training_97427552.jpg
#   inflating: fer2013_data/train/surprise/Training_97440583.jpg
#   inflating: fer2013_data/train/surprise/Training_97444585.jpg
#   inflating: fer2013_data/train/surprise/Training_97615083.jpg
#   inflating: fer2013_data/train/surprise/Training_97658524.jpg
#   inflating: fer2013_data/train/surprise/Training_97667504.jpg
#   inflating: fer2013_data/train/surprise/Training_97675828.jpg
#   inflating: fer2013_data/train/surprise/Training_976799.jpg
#   inflating: fer2013_data/train/surprise/Training_97705054.jpg
#   inflating: fer2013_data/train/surprise/Training_97834691.jpg
#   inflating: fer2013_data/train/surprise/Training_97847754.jpg
#   inflating: fer2013_data/train/surprise/Training_97872221.jpg
#   inflating: fer2013_data/train/surprise/Training_97913254.jpg
#   inflating: fer2013_data/train/surprise/Training_97921487.jpg
#   inflating: fer2013_data/train/surprise/Training_97921838.jpg
#   inflating: fer2013_data/train/surprise/Training_9796387.jpg
#   inflating: fer2013_data/train/surprise/Training_98011942.jpg
#   inflating: fer2013_data/train/surprise/Training_98062605.jpg
#   inflating: fer2013_data/train/surprise/Training_98067546.jpg
#   inflating: fer2013_data/train/surprise/Training_98069171.jpg
#   inflating: fer2013_data/train/surprise/Training_98079493.jpg
#   inflating: fer2013_data/train/surprise/Training_98084340.jpg
#   inflating: fer2013_data/train/surprise/Training_98137653.jpg
#   inflating: fer2013_data/train/surprise/Training_98160615.jpg
#   inflating: fer2013_data/train/surprise/Training_98169661.jpg
#   inflating: fer2013_data/train/surprise/Training_98192978.jpg
#   inflating: fer2013_data/train/surprise/Training_98197769.jpg
#   inflating: fer2013_data/train/surprise/Training_98223737.jpg
#   inflating: fer2013_data/train/surprise/Training_98223779.jpg
#   inflating: fer2013_data/train/surprise/Training_98234175.jpg
#   inflating: fer2013_data/train/surprise/Training_98235103.jpg
#   inflating: fer2013_data/train/surprise/Training_98241018.jpg
#   inflating: fer2013_data/train/surprise/Training_98315142.jpg
#   inflating: fer2013_data/train/surprise/Training_98334836.jpg
#   inflating: fer2013_data/train/surprise/Training_98349673.jpg
#   inflating: fer2013_data/train/surprise/Training_98352897.jpg
#   inflating: fer2013_data/train/surprise/Training_98381187.jpg
#   inflating: fer2013_data/train/surprise/Training_9839279.jpg
#   inflating: fer2013_data/train/surprise/Training_98393554.jpg
#   inflating: fer2013_data/train/surprise/Training_98397319.jpg
#   inflating: fer2013_data/train/surprise/Training_98409862.jpg
#   inflating: fer2013_data/train/surprise/Training_98446939.jpg
#   inflating: fer2013_data/train/surprise/Training_98447563.jpg
#   inflating: fer2013_data/train/surprise/Training_98472640.jpg
#   inflating: fer2013_data/train/surprise/Training_98481914.jpg
#   inflating: fer2013_data/train/surprise/Training_98511054.jpg
#   inflating: fer2013_data/train/surprise/Training_98514521.jpg
#   inflating: fer2013_data/train/surprise/Training_98539906.jpg
#   inflating: fer2013_data/train/surprise/Training_98569897.jpg
#   inflating: fer2013_data/train/surprise/Training_98576352.jpg
#   inflating: fer2013_data/train/surprise/Training_98588726.jpg
#   inflating: fer2013_data/train/surprise/Training_98594534.jpg
#   inflating: fer2013_data/train/surprise/Training_98644924.jpg
#   inflating: fer2013_data/train/surprise/Training_98657632.jpg
#   inflating: fer2013_data/train/surprise/Training_98664620.jpg
#   inflating: fer2013_data/train/surprise/Training_98737557.jpg
#   inflating: fer2013_data/train/surprise/Training_98747340.jpg
#   inflating: fer2013_data/train/surprise/Training_98750930.jpg
#   inflating: fer2013_data/train/surprise/Training_98758885.jpg
#   inflating: fer2013_data/train/surprise/Training_98767792.jpg
#   inflating: fer2013_data/train/surprise/Training_98774734.jpg
#   inflating: fer2013_data/train/surprise/Training_9880069.jpg
#   inflating: fer2013_data/train/surprise/Training_98827007.jpg
#   inflating: fer2013_data/train/surprise/Training_98828949.jpg
#   inflating: fer2013_data/train/surprise/Training_98840937.jpg
#   inflating: fer2013_data/train/surprise/Training_98861159.jpg
#   inflating: fer2013_data/train/surprise/Training_98899707.jpg
#   inflating: fer2013_data/train/surprise/Training_9890261.jpg
#   inflating: fer2013_data/train/surprise/Training_98971238.jpg
#   inflating: fer2013_data/train/surprise/Training_98972491.jpg
#   inflating: fer2013_data/train/surprise/Training_99066709.jpg
#   inflating: fer2013_data/train/surprise/Training_9909756.jpg
#   inflating: fer2013_data/train/surprise/Training_99104204.jpg
#   inflating: fer2013_data/train/surprise/Training_99106305.jpg
#   inflating: fer2013_data/train/surprise/Training_99113691.jpg
#   inflating: fer2013_data/train/surprise/Training_991508.jpg
#   inflating: fer2013_data/train/surprise/Training_99182527.jpg
#   inflating: fer2013_data/train/surprise/Training_99233432.jpg
#   inflating: fer2013_data/train/surprise/Training_99267647.jpg
#   inflating: fer2013_data/train/surprise/Training_99279802.jpg
#   inflating: fer2013_data/train/surprise/Training_99318660.jpg
#   inflating: fer2013_data/train/surprise/Training_9932811.jpg
#   inflating: fer2013_data/train/surprise/Training_99399304.jpg
#   inflating: fer2013_data/train/surprise/Training_99399823.jpg
#   inflating: fer2013_data/train/surprise/Training_99404349.jpg
#   inflating: fer2013_data/train/surprise/Training_9943398.jpg
#   inflating: fer2013_data/train/surprise/Training_99441101.jpg
#   inflating: fer2013_data/train/surprise/Training_99576616.jpg
#   inflating: fer2013_data/train/surprise/Training_99604118.jpg
#   inflating: fer2013_data/train/surprise/Training_99663019.jpg
#   inflating: fer2013_data/train/surprise/Training_99791966.jpg
#   inflating: fer2013_data/train/surprise/Training_99794165.jpg
#   inflating: fer2013_data/train/surprise/Training_99807705.jpg
#   inflating: fer2013_data/train/surprise/Training_99827442.jpg
#   inflating: fer2013_data/train/surprise/Training_99916297.jpg
#   inflating: fer2013_data/train/surprise/Training_99924420.jpg
#   inflating: fer2013_data/train/surprise/Training_99937001.jpg
#   inflating: fer2013_data/train/surprise/Training_99951755.jpg
#   inflating: fer2013_data/train/surprise/Training_99984132.jpg
# Dataset ready.

# %%
# ── Directory paths ────────────────────────────────────────────
train_dir = 'fer2013_data/train'
test_dir  = 'fer2013_data/test'

# Check class folders exist
print('Train classes:', os.listdir(train_dir))
print('Test  classes:', os.listdir(test_dir))
# Out:
# Train classes: ['angry', 'sad', 'surprise', 'disgust', 'happy', 'fear', 'neutral']
# Test  classes: ['angry', 'sad', 'surprise', 'disgust', 'happy', 'fear', 'neutral']

# %% [markdown]
# ## Image Transformations — Rationale
#
# FER-2013 contains 48x48 grayscale face images. The following augmentations were chosen carefully:
#
# | Transformation | Reason |
# |---|---|
# | **Horizontal flip** | Faces look the same mirrored — valid augmentation |
# | **Rotation (±15°)** | Accounts for natural head tilts in real photos |
# | **Zoom (±10%)** | Faces appear at different distances from camera |
# | **Width/Height shift (±10%)** | Face may not be perfectly centred |
# | **Brightness adjustment** | Different lighting conditions in real environments |
# | **Rescale 1/255** | Normalises pixel values to [0, 1] range |
#
# **Transformations deliberately avoided:**
# - Vertical flip — upside-down faces are not realistic
# - Heavy shear/distortion — would destroy facial expression features
# - Channel shift — not applicable for grayscale images
#
# **Note:** ResNet50V2 requires RGB input (3 channels) and minimum 32x32 size.
# We resize images to 224x224 and convert grayscale to RGB by repeating channels.

# %%
# ── Configuration ──────────────────────────────────────────────
IMG_SIZE    = (160, 160)
BATCH_SIZE  = 64
NUM_CLASSES = 7
EPOCHS_UNFROZEN = 35
EPOCHS_FROZEN = 30

# %%
# ── Data Loaders (The Modern tf.data Way) ──────────────────────
print('Loading datasets...')

train_ds = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    validation_split=0.2,
    subset="training",
    seed=42,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical'
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    validation_split=0.2,
    subset="validation",
    seed=42,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical'
)

test_ds = tf.keras.utils.image_dataset_from_directory(
    test_dir,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical',
    shuffle=False
)
class_names = train_ds.class_names
# Out:
# Loading datasets...
# Found 28709 files belonging to 7 classes.
# Using 22968 files for training.
# Found 28709 files belonging to 7 classes.
# Using 5741 files for validation.
# Found 7178 files belonging to 7 classes.

# %%
print("Computing class weights...")
y_labels = np.concatenate([np.argmax(y.numpy(), axis=-1) for x, y in train_ds], axis=0)

class_weights_array = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_labels),
    y=y_labels
)
class_weights = dict(enumerate(class_weights_array))
print("Class Weights:", class_weights)
# Out:
# Computing class weights...
# Class Weights: {0: np.float64(1.0196217703986505), 1: np.float64(9.03896103896104), 2: np.float64(0.998825831702544), 3: np.float64(0.5644491410877098), 4: np.float64(0.8275265717888669), 5: np.float64(0.8558014755197854), 6: np.float64(1.3177280550774526)}

# %%
AUTOTUNE = tf.data.AUTOTUNE

# Prefetch prepares the next batch on the CPU while the GPU is training
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.prefetch(buffer_size=AUTOTUNE)

# %%
# We already extracted y_labels earlier when calculating class weights!
unique_classes, counts = np.unique(y_labels, return_counts=True)
class_counts = dict(zip(class_names, counts))

plt.figure(figsize=(10, 5))
plt.bar(class_counts.keys(), class_counts.values(), color='steelblue')
plt.title('Training Set Class Distribution (80% Split)')
plt.xlabel('Emotion')
plt.ylabel('Number of Images')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

print('Class distribution:', class_counts)
# Out:
# Class distribution: {'angry': np.int64(3218), 'disgust': np.int64(363), 'fear': np.int64(3285), 'happy': np.int64(5813), 'neutral': np.int64(3965), 'sad': np.int64(3834), 'surprise': np.int64(2490)}

# %% [markdown]
# ## ResNet50V2 Transfer Learning — Architecture
#
# **Why transfer learning?**
# ResNet50V2 was pre-trained on ImageNet (1.2 million images, 1000 classes).
# Its early layers already detect edges, textures, and shapes — features also
# useful for facial expression recognition. We fine-tune it for our 7-class task.
#
# **Two-stage training strategy:**
# 1. **Stage 1 — Frozen base:** Train only the new classification head. The ResNet weights stay fixed. This prevents the pre-trained features from being destroyed early on.
# 2. **Stage 2 — Fine-tuning:** Unfreeze the top layers of ResNet and train the whole network at a very low learning rate to gently adapt the features to facial expressions.

# %%
# ── On-GPU Data Augmentation ───────────────────────────────────
data_augmentation = tf.keras.Sequential([
    layers.Rescaling(1./255),
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.028, fill_mode='nearest'),
    layers.RandomZoom(height_factor=0.2, width_factor=0.2, fill_mode='nearest'),
    layers.RandomTranslation(height_factor=0.1, width_factor=0.1, fill_mode='nearest'),
    # layers.RandomBrightness(0.1),
    layers.RandomContrast(0.1),
], name="gpu_augmentation")

# %%
import matplotlib.pyplot as plt
import numpy as np

# 1. Grab one batch of images and labels from the tf.data dataset
sample_images, sample_labels = next(iter(train_ds))

# 2. Apply our standalone augmentation layer to see what the model actually sees
# (training=True tells the layers to actively apply random flips/rotations)
augmented_images = data_augmentation(sample_images, training=True)

fig, axes = plt.subplots(2, 5, figsize=(15, 6))
fig.suptitle('Sample Augmented Training Images', fontsize=14)

for i, ax in enumerate(axes.flat):
    # Convert tensor to numpy and cast to uint8 so matplotlib displays it correctly
    img = augmented_images[i].numpy().astype("uint8")
    ax.imshow(img)
    label_idx = np.argmax(sample_labels[i])
    ax.set_title(class_names[label_idx])
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
# ── Build ResNet50V2 Transfer Learning Model ───────────────────

def build_resnet_model(input_shape=(160, 160, 3), num_classes=7):
    # Load pre-trained ResNet50V2
    base_model = ResNet50V2(
        weights='imagenet',
        include_top=False,
        input_shape=input_shape
    )

    # STAGE 1: Freeze all base model layers entirely
    base_model.trainable = False
    print(f'Base model layers: {len(base_model.layers)}')
    print(f'Trainable layers (frozen): {len([l for l in base_model.layers if l.trainable])}')

    # Build the full model using Functional API
    inputs = tf.keras.Input(shape=input_shape)

    # 1. Apply GPU Augmentation first
    x = data_augmentation(inputs)

    # 2. Pass through ResNet50V2 base
    # training=False is CRITICAL here so BatchNorm layers don't update their statistics
    x = base_model(x, training=False)

    # 3. Custom Classification Head (Your original architecture)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dropout(0.4)(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.3)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = models.Model(inputs, outputs, name='ResNet50V2_FER')
    return model, base_model

resnet_model, base_model = build_resnet_model(
    input_shape=IMG_SIZE + (3,),
    num_classes=NUM_CLASSES
)

resnet_model.summary()
# Out:
# Base model layers: 190
# Trainable layers (frozen): 0
# Model: "ResNet50V2_FER"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_26 (InputLayer)     │ (None, 160, 160, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gpu_augmentation (Sequential)   │ (None, 160, 160, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ resnet50v2 (Functional)         │ (None, 5, 5, 2048)     │    23,564,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_7      │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ (None, 256)            │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_15 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 24,123,143 (92.02 MB)
#  Trainable params: 558,343 (2.13 MB)
#  Non-trainable params: 23,564,800 (89.89 MB)

# %%
# ── Stage 1: Train classification head only (base frozen) ─────

resnet_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

callbacks_stage1 = [
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6, verbose=1)
]

print('Stage 1: Training classification head (base frozen)...')
history_stage1 = resnet_model.fit(
    train_ds,                  # Using tf.data dataset!
    validation_data=val_ds,    # Using tf.data dataset!
    epochs=EPOCHS_FROZEN,
    callbacks=callbacks_stage1,
    class_weight=class_weights,
    verbose=1
)
print('Stage 1 complete.')
# Out:
# Stage 1: Training classification head (base frozen)...
# Epoch 1/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 47s 105ms/step - accuracy: 0.2885 - loss: 1.8338 - val_accuracy: 0.3809 - val_loss: 1.6260 - learning_rate: 0.0010
# Epoch 2/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 36s 99ms/step - accuracy: 0.3373 - loss: 1.7011 - val_accuracy: 0.4006 - val_loss: 1.6027 - learning_rate: 0.0010
# Epoch 3/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 39s 109ms/step - accuracy: 0.3547 - loss: 1.6481 - val_accuracy: 0.4189 - val_loss: 1.5488 - learning_rate: 0.0010
# Epoch 4/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 36s 99ms/step - accuracy: 0.3753 - loss: 1.6115 - val_accuracy: 0.4360 - val_loss: 1.4980 - learning_rate: 0.0010
# Epoch 5/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 35s 98ms/step - accuracy: 0.3907 - loss: 1.5781 - val_accuracy: 0.4435 - val_loss: 1.4927 - learning_rate: 0.0010
# Epoch 6/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 35s 98ms/step - accuracy: 0.3884 - loss: 1.5703 - val_accuracy: 0.4367 - val_loss: 1.4815 - learning_rate: 0.0010
# Epoch 7/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 41s 98ms/step - accuracy: 0.4005 - loss: 1.5517 - val_accuracy: 0.4421 - val_loss: 1.4779 - learning_rate: 0.0010
# Epoch 8/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 35s 98ms/step - accuracy: 0.4087 - loss: 1.5308 - val_accuracy: 0.4506 - val_loss: 1.4591 - learning_rate: 0.0010
# Epoch 9/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 35s 98ms/step - accuracy: 0.4140 - loss: 1.5196 - val_accuracy: 0.4599 - val_loss: 1.4424 - learning_rate: 0.0010
# Epoch 10/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 35s 98ms/step - accuracy: 0.4145 - loss: 1.4940 - val_accuracy: 0.4553 - val_loss: 1.4339 - learning_rate: 0.0010
# Epoch 11/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 35s 98ms/step - accuracy: 0.4193 - loss: 1.4847 - val_accuracy: 0.4618 - val_loss: 1.4192 - learning_rate: 0.0010
# Epoch 12/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 35s 98ms/step - accuracy: 0.4265 - loss: 1.4752 - val_accuracy: 0.4717 - val_loss: 1.4046 - learning_rate: 0.0010
# Epoch 13/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 35s 97ms/step - accuracy: 0.4245 - loss: 1.4743 - val_accuracy: 0.4651 - val_loss: 1.4112 - learning_rate: 0.0010
# Epoch 14/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 35s 97ms/step - accuracy: 0.4322 - loss: 1.4583 - val_accuracy: 0.4738 - val_loss: 1.3866 - learning_rate: 0.0010
# Epoch 15/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 35s 98ms/step - accuracy: 0.4312 - loss: 1.4532 - val_accuracy: 0.4687 - val_loss: 1.4009 - learning_rate: 0.0010
# Epoch 16/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 36s 99ms/step - accuracy: 0.4344 - loss: 1.4451 - val_accuracy: 0.4754 - val_loss: 1.3959 - learning_rate: 0.0010
# Epoch 17/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 36s 100ms/step - accuracy: 0.4400 - loss: 1.4335 - val_accuracy: 0.4846 - val_loss: 1.3819 - learning_rate: 0.0010
# Epoch 18/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - accuracy: 0.4390 - loss: 1.4191 - val_accuracy: 0.4825 - val_loss: 1.3650 - learning_rate: 0.0010
# Epoch 19/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 36s 99ms/step - accuracy: 0.4448 - loss: 1.4164 - val_accuracy: 0.4783 - val_loss: 1.3867 - learning_rate: 0.0010
# Epoch 20/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 39s 110ms/step - accuracy: 0.4458 - loss: 1.4185 - val_accuracy: 0.4905 - val_loss: 1.3599 - learning_rate: 0.0010
# Epoch 21/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 36s 100ms/step - accuracy: 0.4488 - loss: 1.4063 - val_accuracy: 0.4905 - val_loss: 1.3507 - learning_rate: 0.0010
# Epoch 22/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 36s 99ms/step - accuracy: 0.4511 - loss: 1.3960 - val_accuracy: 0.4924 - val_loss: 1.3535 - learning_rate: 0.0010
# Epoch 23/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 36s 99ms/step - accuracy: 0.4498 - loss: 1.3912 - val_accuracy: 0.4893 - val_loss: 1.3569 - learning_rate: 0.0010
# Epoch 24/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 36s 99ms/step - accuracy: 0.4549 - loss: 1.3812 - val_accuracy: 0.4940 - val_loss: 1.3454 - learning_rate: 0.0010
# Epoch 25/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 35s 99ms/step - accuracy: 0.4519 - loss: 1.3847 - val_accuracy: 0.4780 - val_loss: 1.3820 - learning_rate: 0.0010
# Epoch 26/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 36s 99ms/step - accuracy: 0.4503 - loss: 1.3881 - val_accuracy: 0.4943 - val_loss: 1.3484 - learning_rate: 0.0010
# Epoch 27/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.4649 - loss: 1.3778
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 36s 100ms/step - accuracy: 0.4609 - loss: 1.3778 - val_accuracy: 0.4834 - val_loss: 1.3633 - learning_rate: 0.0010
# Epoch 28/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 36s 100ms/step - accuracy: 0.4672 - loss: 1.3535 - val_accuracy: 0.4987 - val_loss: 1.3289 - learning_rate: 5.0000e-04
# Epoch 29/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 36s 99ms/step - accuracy: 0.4741 - loss: 1.3366 - val_accuracy: 0.5022 - val_loss: 1.3327 - learning_rate: 5.0000e-04
# Epoch 30/30
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 36s 99ms/step - accuracy: 0.4731 - loss: 1.3280 - val_accuracy: 0.4989 - val_loss: 1.3191 - learning_rate: 5.0000e-04
# Restoring model weights from the end of the best epoch: 30.
# Stage 1 complete.

# %%
from google.colab import drive
import os

drive.mount('/content/drive')

# Define checkpoint directory
CHECKPOINT_DIR = '/content/drive/MyDrive/checkpoints'
os.makedirs(CHECKPOINT_DIR, exist_ok=True)
print(f'Checkpoint directory created at: {CHECKPOINT_DIR}')
# Save model after Stage 1
stage1_checkpoint_path = os.path.join(
    CHECKPOINT_DIR,
    'resnet50v2_stage1.weights.h5'
)

resnet_model.save_weights(stage1_checkpoint_path)

print(f'Stage 1 weights saved to: {stage1_checkpoint_path}')
# Out:
# Mounted at /content/drive
# Checkpoint directory created at: /content/drive/MyDrive/checkpoints
# Stage 1 weights saved to: /content/drive/MyDrive/checkpoints/resnet50v2_stage1.weights.h5

# %%
base_model.trainable = True

# Freeze bottom layers, keep top 30 unfrozen
fine_tune_from = len(base_model.layers) - 50
for layer in base_model.layers[:fine_tune_from]:
    layer.trainable = False

# CRITICAL: Re-freeze all BatchNorm layers
# If BatchNorm updates during fine-tuning, it ruins the learned representations
for layer in base_model.layers:
    if isinstance(layer, tf.keras.layers.BatchNormalization):
        layer.trainable = False

trainable_count = len([l for l in base_model.layers if l.trainable])
print(f'Fine-tuning top {trainable_count} layers of ResNet50V2')

# Recompile with a much lower learning rate
resnet_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

checkpoint_callback = ModelCheckpoint(
    filepath=os.path.join(CHECKPOINT_DIR, 'resnet50v2_stage2_best.weights.h5'),
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True,
    verbose=1
)

callbacks_stage2 = [
    EarlyStopping(monitor='val_accuracy', patience=7, restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=0.00005, verbose=1),
    checkpoint_callback
]

print('Stage 2: Fine-tuning top layers...')
history_stage2 = resnet_model.fit(
    train_ds,                  # Using tf.data dataset!
    validation_data=val_ds,    # Using tf.data dataset!
    epochs=EPOCHS_UNFROZEN,
    callbacks=callbacks_stage2,
    verbose=1,
    class_weight=class_weights
)

print('Stage 2 complete.')
# Out:
# Fine-tuning top 22 layers of ResNet50V2
# Stage 2: Fine-tuning top layers...
# Epoch 1/35
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.4826 - loss: 1.3203
# Epoch 1: val_loss improved from None to 1.27291, saving model to /content/drive/MyDrive/checkpoints/resnet50v2_stage2_best.weights.h5
#
# Epoch 1: finished saving model to /content/drive/MyDrive/checkpoints/resnet50v2_stage2_best.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 66s 150ms/step - accuracy: 0.4888 - loss: 1.2992 - val_accuracy: 0.5158 - val_loss: 1.2729 - learning_rate: 1.0000e-05
# Epoch 2/35
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.5047 - loss: 1.2621
# Epoch 2: val_loss improved from 1.27291 to 1.25022, saving model to /content/drive/MyDrive/checkpoints/resnet50v2_stage2_best.weights.h5
#
# Epoch 2: finished saving model to /content/drive/MyDrive/checkpoints/resnet50v2_stage2_best.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 49s 136ms/step - accuracy: 0.5039 - loss: 1.2610 - val_accuracy: 0.5290 - val_loss: 1.2502 - learning_rate: 1.0000e-05
# Epoch 3/35
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.5010 - loss: 1.2379
# Epoch 3: val_loss improved from 1.25022 to 1.23398, saving model to /content/drive/MyDrive/checkpoints/resnet50v2_stage2_best.weights.h5
#
# Epoch 3: finished saving model to /content/drive/MyDrive/checkpoints/resnet50v2_stage2_best.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 48s 134ms/step - accuracy: 0.5051 - loss: 1.2371 - val_accuracy: 0.5365 - val_loss: 1.2340 - learning_rate: 1.0000e-05
# Epoch 4/35
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.5094 - loss: 1.2310
# Epoch 4: val_loss improved from 1.23398 to 1.21541, saving model to /content/drive/MyDrive/checkpoints/resnet50v2_stage2_best.weights.h5
#
# Epoch 4: finished saving model to /content/drive/MyDrive/checkpoints/resnet50v2_stage2_best.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 49s 137ms/step - accuracy: 0.5168 - loss: 1.2062 - val_accuracy: 0.5426 - val_loss: 1.2154 - learning_rate: 1.0000e-05
# Epoch 5/35
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.5178 - loss: 1.2036
# Epoch 5: val_loss improved from 1.21541 to 1.20444, saving model to /content/drive/MyDrive/checkpoints/resnet50v2_stage2_best.weights.h5
#
# Epoch 5: finished saving model to /content/drive/MyDrive/checkpoints/resnet50v2_stage2_best.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 50s 140ms/step - accuracy: 0.5241 - loss: 1.1908 - val_accuracy: 0.5464 - val_loss: 1.2044 - learning_rate: 1.0000e-05
# Epoch 6/35
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.5340 - loss: 1.1734
# Epoch 6: val_loss improved from 1.20444 to 1.19304, saving model to /content/drive/MyDrive/checkpoints/resnet50v2_stage2_best.weights.h5
#
# Epoch 6: finished saving model to /content/drive/MyDrive/checkpoints/resnet50v2_stage2_best.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 52s 146ms/step - accuracy: 0.5353 - loss: 1.1594 - val_accuracy: 0.5511 - val_loss: 1.1930 - learning_rate: 1.0000e-05
# Epoch 7/35
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.5369 - loss: 1.1419
# Epoch 7: val_loss improved from 1.19304 to 1.17974, saving model to /content/drive/MyDrive/checkpoints/resnet50v2_stage2_best.weights.h5
#
# Epoch 7: finished saving model to /content/drive/MyDrive/checkpoints/resnet50v2_stage2_best.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 53s 147ms/step - accuracy: 0.5398 - loss: 1.1420 - val_accuracy: 0.5544 - val_loss: 1.1797 - learning_rate: 1.0000e-05
# Epoch 8/35
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.5397 - loss: 1.1461
# Epoch 8: val_loss did not improve from 1.17974
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 70s 114ms/step - accuracy: 0.5432 - loss: 1.1400 - val_accuracy: 0.5574 - val_loss: 1.1800 - learning_rate: 1.0000e-05
# Epoch 9/35
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.5498 - loss: 1.1202
# Epoch 9: val_loss improved from 1.17974 to 1.16541, saving model to /content/drive/MyDrive/checkpoints/resnet50v2_stage2_best.weights.h5
#
# Epoch 9: finished saving model to /content/drive/MyDrive/checkpoints/resnet50v2_stage2_best.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 53s 148ms/step - accuracy: 0.5522 - loss: 1.1114 - val_accuracy: 0.5637 - val_loss: 1.1654 - learning_rate: 1.0000e-05
# Epoch 10/35
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.5528 - loss: 1.1173
# Epoch 10: val_loss improved from 1.16541 to 1.15204, saving model to /content/drive/MyDrive/checkpoints/resnet50v2_stage2_best.weights.h5
#
# Epoch 10: finished saving model to /content/drive/MyDrive/checkpoints/resnet50v2_stage2_best.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 53s 148ms/step - accuracy: 0.5561 - loss: 1.0984 - val_accuracy: 0.5675 - val_loss: 1.1520 - learning_rate: 1.0000e-05
# Epoch 11/35
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.5584 - loss: 1.0891
# Epoch 11: val_loss did not improve from 1.15204
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 43s 119ms/step - accuracy: 0.5630 - loss: 1.0835 - val_accuracy: 0.5658 - val_loss: 1.1601 - learning_rate: 1.0000e-05
# Epoch 12/35
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.5676 - loss: 1.0669
# Epoch 12: val_loss did not improve from 1.15204
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 42s 116ms/step - accuracy: 0.5672 - loss: 1.0706 - val_accuracy: 0.5647 - val_loss: 1.1527 - learning_rate: 1.0000e-05
# Epoch 13/35
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.5652 - loss: 1.0619
# Epoch 13: val_loss improved from 1.15204 to 1.13283, saving model to /content/drive/MyDrive/checkpoints/resnet50v2_stage2_best.weights.h5
#
# Epoch 13: finished saving model to /content/drive/MyDrive/checkpoints/resnet50v2_stage2_best.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 48s 133ms/step - accuracy: 0.5724 - loss: 1.0586 - val_accuracy: 0.5762 - val_loss: 1.1328 - learning_rate: 1.0000e-05
# Epoch 14/35
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.5676 - loss: 1.0531
# Epoch 14: val_loss improved from 1.13283 to 1.12521, saving model to /content/drive/MyDrive/checkpoints/resnet50v2_stage2_best.weights.h5
#
# Epoch 14: finished saving model to /content/drive/MyDrive/checkpoints/resnet50v2_stage2_best.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 50s 140ms/step - accuracy: 0.5733 - loss: 1.0444 - val_accuracy: 0.5767 - val_loss: 1.1252 - learning_rate: 1.0000e-05
# Epoch 15/35
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.5744 - loss: 1.0391
# Epoch 15: val_loss improved from 1.12521 to 1.12128, saving model to /content/drive/MyDrive/checkpoints/resnet50v2_stage2_best.weights.h5
#
# Epoch 15: finished saving model to /content/drive/MyDrive/checkpoints/resnet50v2_stage2_best.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 50s 138ms/step - accuracy: 0.5772 - loss: 1.0402 - val_accuracy: 0.5767 - val_loss: 1.1213 - learning_rate: 1.0000e-05
# Epoch 16/35
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.5849 - loss: 1.0335
# Epoch 16: val_loss improved from 1.12128 to 1.11283, saving model to /content/drive/MyDrive/checkpoints/resnet50v2_stage2_best.weights.h5
#
# Epoch 16: finished saving model to /content/drive/MyDrive/checkpoints/resnet50v2_stage2_best.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 54s 150ms/step - accuracy: 0.5853 - loss: 1.0268 - val_accuracy: 0.5828 - val_loss: 1.1128 - learning_rate: 1.0000e-05
# Epoch 17/35
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.5830 - loss: 1.0118
# Epoch 17: val_loss improved from 1.11283 to 1.11000, saving model to /content/drive/MyDrive/checkpoints/resnet50v2_stage2_best.weights.h5
#
# Epoch 17: finished saving model to /content/drive/MyDrive/checkpoints/resnet50v2_stage2_best.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 52s 145ms/step - accuracy: 0.5849 - loss: 1.0154 - val_accuracy: 0.5847 - val_loss: 1.1100 - learning_rate: 1.0000e-05
# Epoch 18/35
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.5914 - loss: 0.9951
# Epoch 18: val_loss did not improve from 1.11000
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 71s 116ms/step - accuracy: 0.5912 - loss: 1.0080 - val_accuracy: 0.5778 - val_loss: 1.1317 - learning_rate: 1.0000e-05
# Epoch 19/35
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.5895 - loss: 1.0078
# Epoch 19: val_loss improved from 1.11000 to 1.10592, saving model to /content/drive/MyDrive/checkpoints/resnet50v2_stage2_best.weights.h5
#
# Epoch 19: finished saving model to /content/drive/MyDrive/checkpoints/resnet50v2_stage2_best.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 51s 141ms/step - accuracy: 0.5953 - loss: 0.9962 - val_accuracy: 0.5867 - val_loss: 1.1059 - learning_rate: 1.0000e-05
# Epoch 20/35
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.5906 - loss: 0.9913
# Epoch 20: val_loss did not improve from 1.10592
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 43s 119ms/step - accuracy: 0.5934 - loss: 0.9883 - val_accuracy: 0.5861 - val_loss: 1.1061 - learning_rate: 1.0000e-05
# Epoch 21/35
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.5989 - loss: 0.9735
# Epoch 21: val_loss improved from 1.10592 to 1.09561, saving model to /content/drive/MyDrive/checkpoints/resnet50v2_stage2_best.weights.h5
#
# Epoch 21: finished saving model to /content/drive/MyDrive/checkpoints/resnet50v2_stage2_best.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 48s 134ms/step - accuracy: 0.5994 - loss: 0.9796 - val_accuracy: 0.5882 - val_loss: 1.0956 - learning_rate: 1.0000e-05
# Epoch 22/35
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.6046 - loss: 0.9571
# Epoch 22: val_loss did not improve from 1.09561
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 43s 119ms/step - accuracy: 0.6061 - loss: 0.9606 - val_accuracy: 0.5877 - val_loss: 1.1036 - learning_rate: 1.0000e-05
# Epoch 23/35
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.6088 - loss: 0.9447
# Epoch 23: val_loss improved from 1.09561 to 1.09297, saving model to /content/drive/MyDrive/checkpoints/resnet50v2_stage2_best.weights.h5
#
# Epoch 23: finished saving model to /content/drive/MyDrive/checkpoints/resnet50v2_stage2_best.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 50s 140ms/step - accuracy: 0.6089 - loss: 0.9558 - val_accuracy: 0.5901 - val_loss: 1.0930 - learning_rate: 1.0000e-05
# Epoch 24/35
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.6160 - loss: 0.9396
# Epoch 24: val_loss did not improve from 1.09297
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 43s 120ms/step - accuracy: 0.6147 - loss: 0.9459 - val_accuracy: 0.5898 - val_loss: 1.0936 - learning_rate: 1.0000e-05
# Epoch 25/35
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.6152 - loss: 0.9315
# Epoch 25: val_loss improved from 1.09297 to 1.08418, saving model to /content/drive/MyDrive/checkpoints/resnet50v2_stage2_best.weights.h5
#
# Epoch 25: finished saving model to /content/drive/MyDrive/checkpoints/resnet50v2_stage2_best.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 50s 139ms/step - accuracy: 0.6167 - loss: 0.9339 - val_accuracy: 0.5900 - val_loss: 1.0842 - learning_rate: 1.0000e-05
# Epoch 26/35
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.6174 - loss: 0.9289
# Epoch 26: val_loss did not improve from 1.08418
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 47s 130ms/step - accuracy: 0.6181 - loss: 0.9287 - val_accuracy: 0.5879 - val_loss: 1.0996 - learning_rate: 1.0000e-05
# Epoch 27/35
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.6194 - loss: 0.9268
# Epoch 27: val_loss improved from 1.08418 to 1.07929, saving model to /content/drive/MyDrive/checkpoints/resnet50v2_stage2_best.weights.h5
#
# Epoch 27: finished saving model to /content/drive/MyDrive/checkpoints/resnet50v2_stage2_best.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 90s 152ms/step - accuracy: 0.6215 - loss: 0.9210 - val_accuracy: 0.6008 - val_loss: 1.0793 - learning_rate: 1.0000e-05
# Epoch 28/35
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.6295 - loss: 0.9034
# Epoch 28: val_loss improved from 1.07929 to 1.07809, saving model to /content/drive/MyDrive/checkpoints/resnet50v2_stage2_best.weights.h5
#
# Epoch 28: finished saving model to /content/drive/MyDrive/checkpoints/resnet50v2_stage2_best.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 54s 149ms/step - accuracy: 0.6278 - loss: 0.9106 - val_accuracy: 0.5954 - val_loss: 1.0781 - learning_rate: 1.0000e-05
# Epoch 29/35
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.6279 - loss: 0.8944
# Epoch 29: val_loss did not improve from 1.07809
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 47s 129ms/step - accuracy: 0.6323 - loss: 0.8900 - val_accuracy: 0.5964 - val_loss: 1.0796 - learning_rate: 1.0000e-05
# Epoch 30/35
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.6336 - loss: 0.8794
# Epoch 30: val_loss improved from 1.07809 to 1.05910, saving model to /content/drive/MyDrive/checkpoints/resnet50v2_stage2_best.weights.h5
#
# Epoch 30: finished saving model to /content/drive/MyDrive/checkpoints/resnet50v2_stage2_best.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 90s 152ms/step - accuracy: 0.6356 - loss: 0.8850 - val_accuracy: 0.6023 - val_loss: 1.0591 - learning_rate: 1.0000e-05
# Epoch 31/35
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.6394 - loss: 0.8676
# Epoch 31: val_loss did not improve from 1.05910
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 43s 119ms/step - accuracy: 0.6396 - loss: 0.8721 - val_accuracy: 0.6018 - val_loss: 1.0739 - learning_rate: 1.0000e-05
# Epoch 32/35
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.6334 - loss: 0.8954
# Epoch 32: val_loss did not improve from 1.05910
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 41s 115ms/step - accuracy: 0.6354 - loss: 0.8821 - val_accuracy: 0.6027 - val_loss: 1.0679 - learning_rate: 1.0000e-05
# Epoch 33/35
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.6416 - loss: 0.8601
# Epoch 33: val_loss did not improve from 1.05910
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 41s 115ms/step - accuracy: 0.6438 - loss: 0.8616 - val_accuracy: 0.6096 - val_loss: 1.0634 - learning_rate: 1.0000e-05
# Epoch 34/35
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.6478 - loss: 0.8501
# Epoch 34: val_loss did not improve from 1.05910
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 41s 115ms/step - accuracy: 0.6477 - loss: 0.8467 - val_accuracy: 0.6060 - val_loss: 1.0634 - learning_rate: 1.0000e-05
# Epoch 35/35
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.6487 - loss: 0.8538
# Epoch 35: val_loss did not improve from 1.05910
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 41s 115ms/step - accuracy: 0.6475 - loss: 0.8529 - val_accuracy: 0.6011 - val_loss: 1.0674 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 33.
# Stage 2 complete.

# %%
# ── Plot Learning Curves (both stages combined) ────────────────

def plot_learning_curves(history1, history2, title_prefix='ResNet50V2'):
    """
    Combines training history from both stages and plots
    accuracy and loss learning curves.
    """
    # Combine both stages
    acc     = history1.history['accuracy']     + history2.history['accuracy']
    val_acc = history1.history['val_accuracy'] + history2.history['val_accuracy']
    loss    = history1.history['loss']         + history2.history['loss']
    val_loss= history1.history['val_loss']     + history2.history['val_loss']

    stage_boundary = len(history1.history['accuracy'])
    epochs_range = range(1, len(acc) + 1)

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
    fig.suptitle(f'{title_prefix} — Learning Curves', fontsize=14)

    # Accuracy plot
    ax1.plot(epochs_range, acc,     label='Train Accuracy',      color='royalblue')
    ax1.plot(epochs_range, val_acc, label='Validation Accuracy', color='orange', linestyle='--')
    ax1.axvline(x=stage_boundary, color='red', linestyle=':', label='Fine-tuning start')
    ax1.set_title('Accuracy')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Accuracy')
    ax1.legend()
    ax1.grid(alpha=0.3)

    # Loss plot
    ax2.plot(epochs_range, loss,     label='Train Loss',      color='royalblue')
    ax2.plot(epochs_range, val_loss, label='Validation Loss', color='orange', linestyle='--')
    ax2.axvline(x=stage_boundary, color='red', linestyle=':', label='Fine-tuning start')
    ax2.set_title('Loss')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Loss')
    ax2.legend()
    ax2.grid(alpha=0.3)

    plt.tight_layout()
    plt.show()

plot_learning_curves(history_stage1, history_stage2, 'ResNet50V2')

# %%
# ── Evaluate on Test Set ───────────────────────────────────────

print('Evaluating ResNet50V2 on test set...')
test_loss, test_acc = resnet_model.evaluate(test_ds, verbose=1)
print(f'\nTest Loss:     {test_loss:.4f}')
print(f'Test Accuracy: {test_acc:.4f} ({test_acc*100:.2f}%)')
# Out:
# Evaluating ResNet50V2 on test set...
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 71ms/step - accuracy: 0.6138 - loss: 1.0525
#
# Test Loss:     1.0525
# Test Accuracy: 0.6138 (61.38%)

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

print('Generating predictions...')
# 1. Predict directly on the dataset
y_pred_probs = resnet_model.predict(test_ds, verbose=1)
y_pred_classes = np.argmax(y_pred_probs, axis=1)

# 2. Extract true labels from the tf.data pipeline
# We iterate through the test dataset, grab the labels (y), and find the max index
y_true = np.concatenate([np.argmax(y.numpy(), axis=-1) for x, y in test_ds], axis=0)

print('\nClassification Report:')
print(classification_report(
    y_true,
    y_pred_classes,
    target_names=class_names
))
# Out:
# Generating predictions...
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 75ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.51      0.52      0.52       958
#      disgust       0.60      0.63      0.62       111
#         fear       0.54      0.32      0.40      1024
#        happy       0.81      0.83      0.82      1774
#      neutral       0.55      0.62      0.58      1233
#          sad       0.47      0.49      0.48      1247
#     surprise       0.68      0.80      0.73       831
#
#     accuracy                           0.61      7178
#    macro avg       0.60      0.60      0.59      7178
# weighted avg       0.61      0.61      0.61      7178

# %%
# ── Confusion Matrix ───────────────────────────────────────────

cm = confusion_matrix(y_true, y_pred_classes)

plt.figure(figsize=(9, 7))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=class_names,
    yticklabels=class_names
)
plt.title('ResNet50V2 — Confusion Matrix', fontsize=14)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.tight_layout()
plt.show()

print('Confusion matrix displayed.')
# Out:
# Confusion matrix displayed.

# %%
# ── Save the model for reuse ───────────────────────────────────
resnet_model.save('resnet50v2_fer2013.h5')
print('Model saved as resnet50v2_fer2013.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved as resnet50v2_fer2013.h5

# %%
resnet_model.save('my_model.keras')
